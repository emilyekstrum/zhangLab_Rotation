# %% [markdown]
# # Distance Covariance Analysis (DCA) for mouse COMMOT results
#
# - X = SVG or HVG expression matrix
# - Y = spatial coords
#
# author: @emilyekstrum
# 1/26/26

# %%
from dca import dca
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import rpy2.robjects as ro
from rpy2.robjects import pandas2ri
import anndata
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import pdist, squareform

# %%
# load in mouse seurat object
ro.r('library(Seurat)')
ro.r('obj <- readRDS("/Users/emilyekstrum/repos/zhangLab_Rotation/data/processed/seurat_objs/mousebrain_seurat.rds")')
# Out:
# R callback write-console: Loading required package: SeuratObject
#
# R callback write-console: Loading required package: sp
#
# R callback write-console:
# Attaching package: ‘SeuratObject’
#
#
# R callback write-console: The following objects are masked from ‘package:base’:
#
#     intersect, t
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.

# %%
# get mouse seurat obj coordinates
coords = ro.r('''
md <- obj@meta.data
md[, c("imagecol","imagerow")]
''')
coords = pandas2ri.rpy2py(coords)
coords.index = coords.index.astype(str)
coords.columns = ["x", "y"]  


print(coords.head()) # cell ID by location
# Out:
#                          x       y
# AAACAAGTATCTCCCA-1  7410.0  8455.0
# AAACAGAGCGACTCCT-1  3097.0  7905.0
# AAACAGGGTCTATATT-1  7050.0  2327.0
# AAACATTTCCCGGATT-1  8728.0  8111.0
# AAACCCGAACGAAATC-1  6811.0  9351.0

# %%
# load in mouse svgs
mouse_svgs = anndata.read_h5ad("/Users/emilyekstrum/repos/zhangLab_Rotation/data/processed/COMMOT/mouse_svg_lr_sets/mouse_commot_LR_svg.h5ad")

# %%
# get counts matrix for svgs
svgs_counts = mouse_svgs.X.copy()
if isinstance(svgs_counts, np.ndarray):
    svgs_counts = svgs_counts
else:
    svgs_counts = svgs_counts.toarray()
svgs_counts = pd.DataFrame(svgs_counts, index=mouse_svgs.obs_names, columns=mouse_svgs.var_names)
svgs_counts.index = svgs_counts.index.astype(str)

# %%
# check matrix
print(svgs_counts.head())  # cell ID by gene expression
# Out:
#                     Xkr4  Sox17    Mrpl15  Lypla1     Tcea1     Rgs20  \
# AAACAAGTATCTCCCA-1   0.0    0.0  0.000000     0.0  0.000000  0.000000
# AAACAGAGCGACTCCT-1   0.0    0.0  0.693147     0.0  0.693147  0.000000
# AAACAGGGTCTATATT-1   0.0    0.0  0.693147     0.0  0.000000  0.693147
# AAACATTTCCCGGATT-1   0.0    0.0  0.000000     0.0  1.098612  0.000000
# AAACCCGAACGAAATC-1   0.0    0.0  0.000000     0.0  0.000000  0.000000
#
#                      Atp6v1h  Oprk1  Npbwr1    Rb1cc1  ...    mt-Nd4  \
# AAACAAGTATCTCCCA-1  0.000000    0.0     0.0  0.000000  ...  4.553877
# AAACAGAGCGACTCCT-1  0.693147    0.0     0.0  0.693147  ...  5.056246
# AAACAGGGTCTATATT-1  0.693147    0.0     0.0  0.693147  ...  4.787492
# AAACATTTCCCGGATT-1  0.000000    0.0     0.0  0.000000  ...  4.499810
# AAACCCGAACGAAATC-1  0.000000    0.0     0.0  0.693147  ...  4.317488
#
#                       mt-Nd5    mt-Nd6   mt-Cytb     Vamp7     Spry3  Tmlhe  \
# AAACAAGTATCTCCCA-1  2.302585  0.000000  4.852030  0.000000  0.000000    0.0
# AAACAGAGCGACTCCT-1  2.995732  0.693147  5.129899  0.693147  0.693147    0.0
# AAACAGGGTCTATATT-1  2.079442  0.693147  4.897840  0.000000  0.000000    0.0
# AAACATTTCCCGGATT-1  2.197225  1.098612  4.595120  0.000000  0.000000    0.0
# AAACCCGAACGAAATC-1  2.397895  0.000000  4.564348  1.098612  0.000000    0.0
#
#                     AC149090.1  CAAA01118383.1  CAAA01147332.1
# AAACAAGTATCTCCCA-1    0.000000             0.0             0.0
# AAACAGAGCGACTCCT-1    0.693147             0.0             0.0
# AAACAGGGTCTATATT-1    0.693147             0.0             0.0
# AAACATTTCCCGGATT-1    0.000000             0.0             0.0
# AAACCCGAACGAAATC-1    0.693147             0.0             0.0
#
# [5 rows x 16112 columns]

# %%
# align coords and counts matrix
common_cells = svgs_counts.index.intersection(coords.index)
svgs_counts = svgs_counts.loc[common_cells]
svg_coords = coords.loc[common_cells]

# %%
# check that indices match
assert all(svgs_counts.index == svg_coords.index), "Indices do not match!"

# %%
# load im mouse hvgs
mouse_hvgs = anndata.read_h5ad("/Users/emilyekstrum/repos/zhangLab_Rotation/data/processed/COMMOT/mouse_hvg_lr_sets/mouse_commot_LR_hvg.h5ad")

# %%
# get counts matrix for hvgs
hvgs_counts = mouse_hvgs.X.copy()
if isinstance(hvgs_counts, np.ndarray):
    hvgs_counts = hvgs_counts
else:
    hvgs_counts = hvgs_counts.toarray()
hvgs_counts = pd.DataFrame(hvgs_counts, index=mouse_hvgs.obs_names, columns=mouse_hvgs.var_names)
hvgs_counts.index = hvgs_counts.index.astype(str)

# %%
# check matrix
print(hvgs_counts.head())  # cell ID by gene expression
# Out:
#                     Xkr4  Sox17    Mrpl15  Lypla1     Tcea1     Rgs20  \
# AAACAAGTATCTCCCA-1   0.0    0.0  0.000000     0.0  0.000000  0.000000
# AAACAGAGCGACTCCT-1   0.0    0.0  0.693147     0.0  0.693147  0.000000
# AAACAGGGTCTATATT-1   0.0    0.0  0.693147     0.0  0.000000  0.693147
# AAACATTTCCCGGATT-1   0.0    0.0  0.000000     0.0  1.098612  0.000000
# AAACCCGAACGAAATC-1   0.0    0.0  0.000000     0.0  0.000000  0.000000
#
#                      Atp6v1h  Oprk1  Npbwr1    Rb1cc1  ...    mt-Nd4  \
# AAACAAGTATCTCCCA-1  0.000000    0.0     0.0  0.000000  ...  4.553877
# AAACAGAGCGACTCCT-1  0.693147    0.0     0.0  0.693147  ...  5.056246
# AAACAGGGTCTATATT-1  0.693147    0.0     0.0  0.693147  ...  4.787492
# AAACATTTCCCGGATT-1  0.000000    0.0     0.0  0.000000  ...  4.499810
# AAACCCGAACGAAATC-1  0.000000    0.0     0.0  0.693147  ...  4.317488
#
#                       mt-Nd5    mt-Nd6   mt-Cytb     Vamp7     Spry3  Tmlhe  \
# AAACAAGTATCTCCCA-1  2.302585  0.000000  4.852030  0.000000  0.000000    0.0
# AAACAGAGCGACTCCT-1  2.995732  0.693147  5.129899  0.693147  0.693147    0.0
# AAACAGGGTCTATATT-1  2.079442  0.693147  4.897840  0.000000  0.000000    0.0
# AAACATTTCCCGGATT-1  2.197225  1.098612  4.595120  0.000000  0.000000    0.0
# AAACCCGAACGAAATC-1  2.397895  0.000000  4.564348  1.098612  0.000000    0.0
#
#                     AC149090.1  CAAA01118383.1  CAAA01147332.1
# AAACAAGTATCTCCCA-1    0.000000             0.0             0.0
# AAACAGAGCGACTCCT-1    0.693147             0.0             0.0
# AAACAGGGTCTATATT-1    0.693147             0.0             0.0
# AAACATTTCCCGGATT-1    0.000000             0.0             0.0
# AAACCCGAACGAAATC-1    0.693147             0.0             0.0
#
# [5 rows x 16112 columns]

# %%
# align coords and counts matrix
hvg_common_cells = hvgs_counts.index.intersection(coords.index)
hvgs_counts = hvgs_counts.loc[hvg_common_cells]
hvg_coords = coords.loc[hvg_common_cells]

# %%
# check that indices match
assert all(hvgs_counts.index == hvg_coords.index), "Indices do not match!"

# %%
# for SVGS
gene_names = svgs_counts.columns.tolist()
cell_ids = svgs_counts.index.tolist()

print(gene_names[:5])  # first 5 gene names
print(cell_ids[:5])    # first 5 cell IDs
# Out:
# ['Xkr4', 'Sox17', 'Mrpl15', 'Lypla1', 'Tcea1']
# ['AAACAAGTATCTCCCA-1', 'AAACAGAGCGACTCCT-1', 'AAACAGGGTCTATATT-1', 'AAACATTTCCCGGATT-1', 'AAACCCGAACGAAATC-1']

# %%
# for HVGS
hvg_gene_names = hvgs_counts.columns.tolist()
hvg_cell_ids = hvgs_counts.index.tolist()

print(hvg_gene_names[:5])  # first 5 gene names
print(hvg_cell_ids[:5])    # first 5 cell IDs
# Out:
# ['Xkr4', 'Sox17', 'Mrpl15', 'Lypla1', 'Tcea1']
# ['AAACAAGTATCTCCCA-1', 'AAACAGAGCGACTCCT-1', 'AAACAGGGTCTATATT-1', 'AAACATTTCCCGGATT-1', 'AAACCCGAACGAAATC-1']

# %%
# inputs for DCA 
# need X -> standardized (z scored) gene x cell matrix

scaler = StandardScaler()
#X_svg = pd.DataFrame(scaler.fit_transform(svgs_counts), index=svgs_counts.index, columns=svgs_counts.columns)
X_hvg = pd.DataFrame(scaler.fit_transform(hvgs_counts), index=hvgs_counts.index, columns=hvgs_counts.columns)

# %%
# transpose matrices to get gene x cell
#X_svg = X_svg.T
X_hvg = X_hvg.T

X_hvg.head()
# Out:
#         AAACAAGTATCTCCCA-1  AAACAGAGCGACTCCT-1  AAACAGGGTCTATATT-1  \
# Xkr4              0.000000            0.000000            0.000000
# Sox17            -0.319774           -0.319774           -0.319774
# Mrpl15           -0.734810            0.869913            0.869913
# Lypla1           -0.575309           -0.575309           -0.575309
# Tcea1            -0.812530            0.716311           -0.812530
#
#         AAACATTTCCCGGATT-1  AAACCCGAACGAAATC-1  AAACCGGAAATGTTAA-1  \
# Xkr4              0.000000            0.000000            0.000000
# Sox17            -0.319774           -0.319774            2.737599
# Mrpl15           -0.734810           -0.734810            0.869913
# Lypla1           -0.575309           -0.575309           -0.575309
# Tcea1             1.610626           -0.812530           -0.812530
#
#         AAACCGGGTAGGTACC-1  AAACGAGACGGTTGAT-1  AAACTGCTGGCTCCAA-1  \
# Xkr4              0.000000            0.000000            0.000000
# Sox17            -0.319774           -0.319774           -0.319774
# Mrpl15           -0.734810            0.869913           -0.734810
# Lypla1           -0.575309            1.353987           -0.575309
# Tcea1             0.716311            0.716311           -0.812530
#
#         AAACTTGCAAACGTAT-1  ...  TTGTGAGGCATGACGC-1  TTGTGCAGCCACGTCA-1  \
# Xkr4              0.000000  ...            0.000000            0.000000
# Sox17            -0.319774  ...           -0.319774           -0.319774
# Mrpl15           -0.734810  ...            0.869913           -0.734810
# Lypla1           -0.575309  ...            1.353987           -0.575309
# Tcea1            -0.812530  ...           -0.812530           -0.812530
#
#         TTGTGGCCCTGACAGT-1  TTGTGTATGCCACCAA-1  TTGTGTTTCCCGAAAG-1  \
# Xkr4              0.000000            0.000000            0.000000
# Sox17            -0.319774           -0.319774           -0.319774
# Mrpl15           -0.734810           -0.734810           -0.734810
# Lypla1           -0.575309           -0.575309           -0.575309
# Tcea1             0.716311           -0.812530           -0.812530
#
#         TTGTTAGCAAATTCGA-1  TTGTTCAGTGTGCTAC-1  TTGTTGTGTGTCAAGA-1  \
# Xkr4              0.000000            0.000000            0.000000
# Sox17            -0.319774           -0.319774           -0.319774
# Mrpl15            0.869913           -0.734810            0.869913
# Lypla1            1.353987           -0.575309            1.353987
# Tcea1             0.716311            0.716311           -0.812530
#
#         TTGTTTCATTAGTCTA-1  TTGTTTCCATACAACT-1
# Xkr4              0.000000            0.000000
# Sox17            -0.319774           -0.319774
# Mrpl15           -0.734810            0.869913
# Lypla1           -0.575309           -0.575309
# Tcea1             1.610626            1.610626
#
# [5 rows x 1640 columns]

# %%
# convert gene by cell matrices to arrays
#X_svg_array = X_svg.values
X_hvg_array = X_hvg.values

# %%
X_hvg_array
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.31977388, -0.31977388, -0.31977388, ..., -0.31977388,
#         -0.31977388, -0.31977388],
#        [-0.73481012,  0.8699128 ,  0.8699128 , ...,  0.8699128 ,
#         -0.73481012,  0.8699128 ],
#        ...,
#        [-1.24452374, -0.09148907, -0.09148907, ...,  1.06154561,
#         -0.09148907, -0.09148907],
#        [-0.37689703, -0.37689703, -0.37689703, ..., -0.37689703,
#         -0.37689703, -0.37689703],
#        [-0.10234466, -0.10234466, -0.10234466, ..., -0.10234466,
#         -0.10234466, -0.10234466]], shape=(16112, 1640))

# %%
# dependent distance matrix from coordinates (cells x cells)

dist_matrix = squareform(pdist(hvg_coords.values, metric='euclidean'))
#dist_matrix = pd.DataFrame(dist_matrix, index=svg_coords.index, columns=svg_coords.index)

# %%
dist_matrix
# Out:
# array([[   0.        , 4347.92697731, 6138.56530469, ..., 2854.21968321,
#         5099.71107025, 5198.62452962],
#        [4347.92697731,    0.        , 6836.6872826 , ..., 2348.73093393,
#         7056.3992234 , 5923.07285115],
#        [6138.56530469, 6836.6872826 ,    0.        , ..., 4805.88576643,
#         1949.00102617,  993.18527979],
#        ...,
#        [2854.21968321, 2348.73093393, 4805.88576643, ...,    0.        ,
#         4748.40194171, 3830.13485402],
#        [5099.71107025, 7056.3992234 , 1949.00102617, ..., 4748.40194171,
#            0.        , 1808.8830808 ],
#        [5198.62452962, 5923.07285115,  993.18527979, ..., 3830.13485402,
#         1808.8830808 ,    0.        ]], shape=(1640, 1640))

# %%
# DCA parameters
k = 15 # number of dims

# %%
# run DCA 

hvg_U_list, hvg_dcovs = dca(
    Xs=[X_hvg_array],               # list of datasets to project (genes x cells)
    Ds=[dist_matrix],               # list of dependent distance matrices (cells x cells)
    num_dca_dimensions=k,           # number of DCA dimensions to learn
    num_iters_per_dataset=1,        # number of times to run DCA per dataset, default 1
    num_iters_foreach_dim=30,       # number of iterations to run for each dimension, default 30
    num_stoch_batch_samples=100,    # number of cells to use in stochastic batches when estimating gradients, default 100
    num_samples_to_compute_stepwise_dcov=1000, # number of samples to use when computing distance covariance, default 1000
    percent_increase_criterion=0.01 # convergence criterion, default 0.01
)
# Out:
# dca dimension 1
#    step 1: dcov = 3.1145459100365125
#      batches:
# ................
#    step 2: dcov = 74.37723836587762
#      batches:
# ................
#    step 3: dcov = 70.33384883788426
#      batches:
# ................
#    step 4: dcov = 74.8564865761465
#      batches:
# ................
#    step 5: dcov = 78.74230535009247
#      batches:
# ................
#    step 6: dcov = 82.7602638453783
#      batches:
# ................
#    step 7: dcov = 84.96176226373395
#      batches:
# ................
#    step 8: dcov = 83.88571620062174
#      batches:
# ................
#    step 9: dcov = 83.38559725955388
#      batches:
# ................
#    step 10: dcov = 88.12704689202414
#      batches:
# ................
#    step 11: dcov = 84.80811131670524
#      batches:
# ................
#    step 12: dcov = 87.28870647260317
#      batches:
# ................
#    step 13: dcov = 88.60115383140842
#      batches:
# ................
#    step 14: dcov = 88.88519761049362
#      batches:
# ................
#    step 15: dcov = 91.12391047993263
#      batches:
# ................
#    step 16: dcov = 88.7000835849313
#      batches:
# ................
#    step 17: dcov = 87.17223066934655
#      batches:
# ................
#    step 18: dcov = 92.06827341770654
#      batches:
# ................
#    step 19: dcov = 87.41264647417538
#      batches:
# ................
#    step 20: dcov = 93.70125411707593
#      batches:
# ................
#    step 21: dcov = 89.4981469011055
#      batches:
# ................
#    step 22: dcov = 94.88800659095806
#      batches:
# ................
#    step 23: dcov = 91.52626045997735
#      batches:
# ................
#    step 24: dcov = 91.52241509001193
#      batches:
# ................
#    step 25: dcov = 92.21796840660838
#      batches:
# ................
#    step 26: dcov = 95.17833436238081
#      batches:
# ................
#    step 27: dcov = 93.96725501053618
#      batches:
# ................
#    step 28: dcov = 93.47315169593816
#      batches:
# ................
#    step 29: dcov = 95.47462445153091
#      batches:
# ................
#    step 30: dcov = 95.27690710410536
#      batches:
# ................
#
# dca dimension 2
#    step 1: dcov = 2.317005130761397
#      batches:
# ................
#    step 2: dcov = 50.91220650730217
#      batches:
# ................
#    step 3: dcov = 54.050877214318646
#      batches:
# ................
#    step 4: dcov = 53.841795537821014
#      batches:
# ................
#    step 5: dcov = 54.04611316620489
#      batches:
# ................
#    step 6: dcov = 56.40754693476266
#      batches:
# ................
#    step 7: dcov = 61.768443221676236
#      batches:
# ................
#    step 8: dcov = 58.50128248627698
#      batches:
# ................
#    step 9: dcov = 62.44451802458235
#      batches:
# ................
#    step 10: dcov = 63.07178520691573
#      batches:
# ................
#    step 11: dcov = 60.34860897481225
#      batches:
# ................
#    step 12: dcov = 64.9974714054936
#      batches:
# ................
#    step 13: dcov = 65.76596030078746
#      batches:
# ................
#    step 14: dcov = 62.102101816141854
#      batches:
# ................
#    step 15: dcov = 65.17116704085092
#      batches:
# ................
#    step 16: dcov = 64.55621029774683
#      batches:
# ................
#    step 17: dcov = 65.63305879495176
#      batches:
# ................
#    step 18: dcov = 66.20416362076163
#      batches:
# ................
#    step 19: dcov = 67.56311310507775
#      batches:
# ................
#    step 20: dcov = 67.90378478322958
#      batches:
# ................
#    step 21: dcov = 67.78844070831246
#      batches:
# ................
#    step 22: dcov = 66.81158247486412
#      batches:
# ................
#    step 23: dcov = 69.3598401128736
#      batches:
# ................
#    step 24: dcov = 69.98478487918024
#      batches:
# ................
#    step 25: dcov = 70.59281430093482
#      batches:
# ................
#    step 26: dcov = 69.61794325566892
#      batches:
# ................
#    step 27: dcov = 69.28902676834777
#      batches:
# ................
#    step 28: dcov = 71.43986077856025
#      batches:
# ................
#    step 29: dcov = 68.74606961747118
#      batches:
# ................
#    step 30: dcov = 70.04898322487638
#      batches:
# ................
#
# dca dimension 3
#    step 1: dcov = 2.5625709380759543
#      batches:
# ................
#    step 2: dcov = 35.60479580237517
#      batches:
# ................
#    step 3: dcov = 39.40186130556325
#      batches:
# ................
#    step 4: dcov = 40.757548350137846
#      batches:
# ................
#    step 5: dcov = 40.208781216826154
#      batches:
# ................
#    step 6: dcov = 43.701880846986306
#      batches:
# ................
#    step 7: dcov = 42.561385914284465
#      batches:
# ................
#    step 8: dcov = 42.47007579880694
#      batches:
# ................
#    step 9: dcov = 43.97070853882595
#      batches:
# ................
#    step 10: dcov = 46.08856261201555
#      batches:
# ................
#    step 11: dcov = 44.8908460662651
#      batches:
# ................
#    step 12: dcov = 43.06983959988239
#      batches:
# ................
#    step 13: dcov = 46.68684090656961
#      batches:
# ................
#    step 14: dcov = 49.102053299927725
#      batches:
# ................
#    step 15: dcov = 48.82918988539909
#      batches:
# ................
#    step 16: dcov = 51.36696535477867
#      batches:
# ................
#    step 17: dcov = 49.910926970323736
#      batches:
# ................
#    step 18: dcov = 49.86981593537942
#      batches:
# ................
#    step 19: dcov = 48.55407648526376
#      batches:
# ................
#    step 20: dcov = 47.817688816652506
#      batches:
# ................
#    step 21: dcov = 48.755724165403464
#      batches:
# ................
#    step 22: dcov = 49.00303595566925
#      batches:
# ................
#    step 23: dcov = 49.46589572365461
#      batches:
# ................
#    step 24: dcov = 50.26143508061942
#      batches:
# ................
#    step 25: dcov = 53.05114811743929
#      batches:
# ................
#    step 26: dcov = 50.63947183576538
#      batches:
# ................
#    step 27: dcov = 50.277497426315506
#      batches:
# ................
#    step 28: dcov = 49.979075609245825
#      batches:
# ................
#    step 29: dcov = 49.505014873081464
#      batches:
# ................
#    step 30: dcov = 49.57921109972859
#      batches:
# ................
#
# dca dimension 4
#    step 1: dcov = 2.547040836949743
#      batches:
# ................
#    step 2: dcov = 10.44881428804991
#      batches:
# ................
#    step 3: dcov = 9.51877051840202
#      batches:
# ................
#    step 4: dcov = 13.765507247510971
#      batches:
# ................
#    step 5: dcov = 12.838111777479188
#      batches:
# ................
#    step 6: dcov = 18.781945119281485
#      batches:
# ................
#    step 7: dcov = 12.284099685497761
#      batches:
# ................
#    step 8: dcov = 14.247822277461202
#      batches:
# ................
#    step 9: dcov = 18.410978001065473
#      batches:
# ................
#    step 10: dcov = 19.216964191730042
#      batches:
# ................
#    step 11: dcov = 19.447326651440257
#      batches:
# ................
#    step 12: dcov = 19.074569039888143
#      batches:
# ................
#    step 13: dcov = 23.647056524800703
#      batches:
# ................
#    step 14: dcov = 26.821390698459147
#      batches:
# ................
#    step 15: dcov = 27.47380912544568
#      batches:
# ................
#    step 16: dcov = 25.990332139156802
#      batches:
# ................
#    step 17: dcov = 28.79382924888688
#      batches:
# ................
#    step 18: dcov = 30.421576193568114
#      batches:
# ................
#    step 19: dcov = 29.164349779550218
#      batches:
# ................
#    step 20: dcov = 33.160412522992125
#      batches:
# ................
#    step 21: dcov = 31.710168371029148
#      batches:
# ................
#    step 22: dcov = 33.44359066706569
#      batches:
# ................
#    step 23: dcov = 35.46302723605542
#      batches:
# ................
#    step 24: dcov = 33.141866364959036
#      batches:
# ................
#    step 25: dcov = 33.61095227504366
#      batches:
# ................
#    step 26: dcov = 36.07062828561687
#      batches:
# ................
#    step 27: dcov = 34.88802421709287
#      batches:
# ................
#    step 28: dcov = 35.67647195993123
#      batches:
# ................
#    step 29: dcov = 36.97278843663988
#      batches:
# ................
#    step 30: dcov = 35.24189392670648
#      batches:
# ................
#
# dca dimension 5
#    step 1: dcov = 2.2289906607104966
#      batches:
# ................
#    step 2: dcov = 8.984009871766016
#      batches:
# ................
#    step 3: dcov = 10.624008255958218
#      batches:
# ................
#    step 4: dcov = 11.42315723750428
#      batches:
# ................
#    step 5: dcov = 13.202518358989037
#      batches:
# ................
#    step 6: dcov = 17.287038384384314
#      batches:
# ................
#    step 7: dcov = 10.481769477710628
#      batches:
# ................
#    step 8: dcov = 18.218191268548484
#      batches:
# ................
#    step 9: dcov = 21.168358198475477
#      batches:
# ................
#    step 10: dcov = 21.530615487964788
#      batches:
# ................
#    step 11: dcov = 18.26856518891359
#      batches:
# ................
#    step 12: dcov = 19.81381511046228
#      batches:
# ................
#    step 13: dcov = 23.220685358774524
#      batches:
# ................
#    step 14: dcov = 22.000057905895684
#      batches:
# ................
#    step 15: dcov = 24.15226220274248
#      batches:
# ................
#    step 16: dcov = 24.643790079754584
#      batches:
# ................
#    step 17: dcov = 27.88464328643879
#      batches:
# ................
#    step 18: dcov = 26.82437158321448
#      batches:
# ................
#    step 19: dcov = 27.890177412331454
#      batches:
# ................
#    step 20: dcov = 29.671204559796234
#      batches:
# ................
#    step 21: dcov = 29.770414498051498
#      batches:
# ................
#    step 22: dcov = 32.08235451250632
#      batches:
# ................
#    step 23: dcov = 33.82286259183251
#      batches:
# ................
#    step 24: dcov = 31.47706032319607
#      batches:
# ................
#    step 25: dcov = 33.38395716276175
#      batches:
# ................
#    step 26: dcov = 34.111187609367896
#      batches:
# ................
#    step 27: dcov = 34.32813653506833
#      batches:
# ................
#    step 28: dcov = 35.746662852981316
#      batches:
# ................
#    step 29: dcov = 36.923121207952896
#      batches:
# ................
#    step 30: dcov = 36.86971670217163
#      batches:
# ................
#
# dca dimension 6
#    step 1: dcov = 2.0945752160376343
#      batches:
# ................
#    step 2: dcov = 9.227796309515028
#      batches:
# ................
#    step 3: dcov = 8.22418778759662
#      batches:
# ................
#    step 4: dcov = 10.415265085760545
#      batches:
# ................
#    step 5: dcov = 9.729675082505022
#      batches:
# ................
#    step 6: dcov = 12.092291628869665
#      batches:
# ................
#    step 7: dcov = 12.21122366799806
#      batches:
# ................
#    step 8: dcov = 15.033985228109051
#      batches:
# ................
#    step 9: dcov = 13.073601627411051
#      batches:
# ................
#    step 10: dcov = 13.972471205430441
#      batches:
# ................
#    step 11: dcov = 13.4155912182566
#      batches:
# ................
#    step 12: dcov = 15.835442957130306
#      batches:
# ................
#    step 13: dcov = 18.01375737984075
#      batches:
# ................
#    step 14: dcov = 20.401564614576753
#      batches:
# ................
#    step 15: dcov = 19.071013778585975
#      batches:
# ................
#    step 16: dcov = 19.848166155292148
#      batches:
# ................
#    step 17: dcov = 20.121530227059868
#      batches:
# ................
#    step 18: dcov = 25.061146542257816
#      batches:
# ................
#    step 19: dcov = 22.806243501252318
#      batches:
# ................
#    step 20: dcov = 27.23005176618482
#      batches:
# ................
#    step 21: dcov = 27.594515130300127
#      batches:
# ................
#    step 22: dcov = 28.068575384765694
#      batches:
# ................
#    step 23: dcov = 29.564331935707667
#      batches:
# ................
#    step 24: dcov = 29.971553674647716
#      batches:
# ................
#    step 25: dcov = 30.921618879411646
#      batches:
# ................
#    step 26: dcov = 33.09258626183844
#      batches:
# ................
#    step 27: dcov = 33.323672694736736
#      batches:
# ................
#    step 28: dcov = 33.03260966829652
#      batches:
# ................
#    step 29: dcov = 34.50812801093396
#      batches:
# ................
#    step 30: dcov = 36.39150149808463
#      batches:
# ................
#
# dca dimension 7
#    step 1: dcov = 1.9622628848776844
#      batches:
# ................
#    step 2: dcov = 7.0136898281131534
#      batches:
# ................
#    step 3: dcov = 7.673944559409017
#      batches:
# ................
#    step 4: dcov = 10.653782196279785
#      batches:
# ................
#    step 5: dcov = 11.522346212081558
#      batches:
# ................
#    step 6: dcov = 12.873908177529328
#      batches:
# ................
#    step 7: dcov = 15.382075936242932
#      batches:
# ................
#    step 8: dcov = 15.821783541907058
#      batches:
# ................
#    step 9: dcov = 16.128372501434217
#      batches:
# ................
#    step 10: dcov = 12.060089897191755
#      batches:
# ................
#    step 11: dcov = 12.988562706459
#      batches:
# ................
#    step 12: dcov = 11.725396927663859
#      batches:
# ................
#    step 13: dcov = 13.587138054493419
#      batches:
# ................
#    step 14: dcov = 16.349695416099266
#      batches:
# ................
#    step 15: dcov = 15.710915869215142
#      batches:
# ................
#    step 16: dcov = 16.469580550908855
#      batches:
# ................
#    step 17: dcov = 18.20502610178703
#      batches:
# ................
#    step 18: dcov = 15.558510507037566
#      batches:
# ................
#    step 19: dcov = 18.256931741032602
#      batches:
# ................
#    step 20: dcov = 19.308253778949652
#      batches:
# ................
#    step 21: dcov = 22.07006341600657
#      batches:
# ................
#    step 22: dcov = 22.271110488675028
#      batches:
# ................
#    step 23: dcov = 20.82947137927574
#      batches:
# ................
#    step 24: dcov = 22.671171767436324
#      batches:
# ................
#    step 25: dcov = 24.876048848474728
#      batches:
# ................
#    step 26: dcov = 24.138489530787556
#      batches:
# ................
#    step 27: dcov = 25.119831285883
#      batches:
# ................
#    step 28: dcov = 25.48658823316727
#      batches:
# ................
#    step 29: dcov = 27.71927727581199
#      batches:
# ................
#    step 30: dcov = 26.563108986357435
#      batches:
# ................
#
# dca dimension 8
#    step 1: dcov = 2.032387606916656
#      batches:
# ................
#    step 2: dcov = 11.907541034486197
#      batches:
# ................
#    step 3: dcov = 8.77757153976686
#      batches:
# ................
#    step 4: dcov = 10.00185207963288
#      batches:
# ................
#    step 5: dcov = 12.203405770742824
#      batches:
# ................
#    step 6: dcov = 11.050923796728712
#      batches:
# ................
#    step 7: dcov = 16.48495415088037
#      batches:
# ................
#    step 8: dcov = 13.105011113243448
#      batches:
# ................
#    step 9: dcov = 12.455157953916675
#      batches:
# ................
#    step 10: dcov = 15.028426644150853
#      batches:
# ................
#    step 11: dcov = 16.126852967568066
#      batches:
# ................
#    step 12: dcov = 21.080770668544695
#      batches:
# ................
#    step 13: dcov = 20.287458144751852
#      batches:
# ................
#    step 14: dcov = 21.60422774527251
#      batches:
# ................
#    step 15: dcov = 19.9722884561759
#      batches:
# ................
#    step 16: dcov = 20.17984097454708
#      batches:
# ................
#    step 17: dcov = 23.50954870588586
#      batches:
# ................
#    step 18: dcov = 23.686917056830016
#      batches:
# ................
#    step 19: dcov = 27.01933879110355
#      batches:
# ................
#    step 20: dcov = 26.112420338513914
#      batches:
# ................
#    step 21: dcov = 26.610719690900154
#      batches:
# ................
#    step 22: dcov = 30.122256587979482
#      batches:
# ................
#    step 23: dcov = 30.133491407264938
#      batches:
# ................
#    step 24: dcov = 31.44703162780808
#      batches:
# ................
#    step 25: dcov = 30.998247419132635
#      batches:
# ................
#    step 26: dcov = 32.58333362693638
#      batches:
# ................
#    step 27: dcov = 34.57177069084882
#      batches:
# ................
#    step 28: dcov = 33.517527409157935
#      batches:
# ................
#    step 29: dcov = 34.93059715885116
#      batches:
# ................
#    step 30: dcov = 34.29909080466176
#      batches:
# ................
#
# dca dimension 9
#    step 1: dcov = 1.959592415883303
#      batches:
# ................
#    step 2: dcov = 8.280350599521451
#      batches:
# ................
#    step 3: dcov = 8.506858485090817
#      batches:
# ................
#    step 4: dcov = 8.03083858374813
#      batches:
# ................
#    step 5: dcov = 9.19553856234018
#      batches:
# ................
#    step 6: dcov = 8.973036270061256
#      batches:
# ................
#    step 7: dcov = 12.58719916234396
#      batches:
# ................
#    step 8: dcov = 9.337224747825461
#      batches:
# ................
#    step 9: dcov = 12.458394560902985
#      batches:
# ................
#    step 10: dcov = 11.854540528821419
#      batches:
# ................
#    step 11: dcov = 16.40046365030111
#      batches:
# ................
#    step 12: dcov = 16.09312245405988
#      batches:
# ................
#    step 13: dcov = 16.826386514903188
#      batches:
# ................
#    step 14: dcov = 18.323005172683168
#      batches:
# ................
#    step 15: dcov = 16.87140959972603
#      batches:
# ................
#    step 16: dcov = 17.663044070794072
#      batches:
# ................
#    step 17: dcov = 20.157219841650235
#      batches:
# ................
#    step 18: dcov = 21.435114482981533
#      batches:
# ................
#    step 19: dcov = 22.984466272416384
#      batches:
# ................
#    step 20: dcov = 23.18260071954565
#      batches:
# ................
#    step 21: dcov = 23.12859360467412
#      batches:
# ................
#    step 22: dcov = 27.320179528229296
#      batches:
# ................
#    step 23: dcov = 27.04206386629594
#      batches:
# ................
#    step 24: dcov = 27.481521301241173
#      batches:
# ................
#    step 25: dcov = 28.68427383285895
#      batches:
# ................
#    step 26: dcov = 29.49584259303227
#      batches:
# ................
#    step 27: dcov = 30.525972733127535
#      batches:
# ................
#    step 28: dcov = 28.84322955630567
#      batches:
# ................
#    step 29: dcov = 31.462956565420413
#      batches:
# ................
#    step 30: dcov = 31.73238210955304
#      batches:
# ................
#
# dca dimension 10
#    step 1: dcov = 1.5782378571291482
#      batches:
# ................
#    step 2: dcov = 8.564324879969428
#      batches:
# ................
#    step 3: dcov = 7.742385953049233
#      batches:
# ................
#    step 4: dcov = 8.327071915665888
#      batches:
# ................
#    step 5: dcov = 7.219204006777849
#      batches:
# ................
#    step 6: dcov = 6.3543625338518375
#      batches:
# ................
#    step 7: dcov = 7.722189081255838
#      batches:
# ................
#    step 8: dcov = 6.385727583955797
#      batches:
# ................
#    step 9: dcov = 7.65129200883656
#      batches:
# ................
#    step 10: dcov = 7.363837548168656
#      batches:
# ................
#    step 11: dcov = 8.286291730902912
#      batches:
# ................
#    step 12: dcov = 10.422104430791919
#      batches:
# ................
#    step 13: dcov = 10.890546199554736
#      batches:
# ................
#    step 14: dcov = 9.688590410008283
#      batches:
# ................
#    step 15: dcov = 8.590129899604525
#      batches:
# ................
#    step 16: dcov = 9.344208093385774
#      batches:
# ................
#    step 17: dcov = 9.97678432981145
#      batches:
# ................
#    step 18: dcov = 9.876721159952291
#      batches:
# ................
#    step 19: dcov = 9.987662457373979
#      batches:
# ................
#    step 20: dcov = 11.053319133243967
#      batches:
# ................
#    step 21: dcov = 13.000989803871125
#      batches:
# ................
#    step 22: dcov = 12.847980067538325
#      batches:
# ................
#    step 23: dcov = 15.271977965540021
#      batches:
# ................
#    step 24: dcov = 15.291187133290943
#      batches:
# ................
#    step 25: dcov = 17.097934456285266
#      batches:
# ................
#    step 26: dcov = 20.10129304942606
#      batches:
# ................
#    step 27: dcov = 19.943649728411124
#      batches:
# ................
#    step 28: dcov = 21.72049511138164
#      batches:
# ................
#    step 29: dcov = 22.008989041334615
#      batches:
# ................
#    step 30: dcov = 22.76445880605573
#      batches:
# ................
#
# dca dimension 11
#    step 1: dcov = 2.02493542957554
#      batches:
# ................
#    step 2: dcov = 7.670018578418372
#      batches:
# ................
#    step 3: dcov = 7.790224858490956
#      batches:
# ................
#    step 4: dcov = 9.181332371205892
#      batches:
# ................
#    step 5: dcov = 8.14771810527133
#      batches:
# ................
#    step 6: dcov = 7.327777068465507
#      batches:
# ................
#    step 7: dcov = 7.681485098716816
#      batches:
# ................
#    step 8: dcov = 5.7558578882258535
#      batches:
# ................
#    step 9: dcov = 7.417120945531976
#      batches:
# ................
#    step 10: dcov = 7.421617466182095
#      batches:
# ................
#    step 11: dcov = 9.154810528659794
#      batches:
# ................
#    step 12: dcov = 9.475379210810194
#      batches:
# ................
#    step 13: dcov = 9.468087376093326
#      batches:
# ................
#    step 14: dcov = 10.737668705158564
#      batches:
# ................
#    step 15: dcov = 10.412107928302097
#      batches:
# ................
#    step 16: dcov = 12.12771698106916
#      batches:
# ................
#    step 17: dcov = 12.807833009180538
#      batches:
# ................
#    step 18: dcov = 12.921173025197255
#      batches:
# ................
#    step 19: dcov = 15.164539331338755
#      batches:
# ................
#    step 20: dcov = 14.602383103892913
#      batches:
# ................
#    step 21: dcov = 15.885145444516086
#      batches:
# ................
#    step 22: dcov = 16.750198986497978
#      batches:
# ................
#    step 23: dcov = 19.233157004244966
#      batches:
# ................
#    step 24: dcov = 18.0042560842753
#      batches:
# ................
#    step 25: dcov = 19.134159230573328
#      batches:
# ................
#    step 26: dcov = 22.52617168441197
#      batches:
# ................
#    step 27: dcov = 21.180495002981118
#      batches:
# ................
#    step 28: dcov = 23.221120617698784
#      batches:
# ................
#    step 29: dcov = 23.235388410947223
#      batches:
# ................
#    step 30: dcov = 24.93639133300039
#      batches:
# ................
#
# dca dimension 12
#    step 1: dcov = 1.751162470702958
#      batches:
# ................
#    step 2: dcov = 6.443934713247487
#      batches:
# ................
#    step 3: dcov = 7.852047012886848
#      batches:
# ................
#    step 4: dcov = 6.68078093016395
#      batches:
# ................
#    step 5: dcov = 7.9475999648292
#      batches:
# ................
#    step 6: dcov = 9.035016336735097
#      batches:
# ................
#    step 7: dcov = 7.363574949258941
#      batches:
# ................
#    step 8: dcov = 8.585468147159903
#      batches:
# ................
#    step 9: dcov = 6.923596624741179
#      batches:
# ................
#    step 10: dcov = 10.171871490877718
#      batches:
# ................
#    step 11: dcov = 4.428487135461708
#      batches:
# ................
#    step 12: dcov = 5.639141010985826
#      batches:
# ................
#    step 13: dcov = 8.761366009134722
#      batches:
# ................
#    step 14: dcov = 9.371523604768681
#      batches:
# ................
#    step 15: dcov = 12.711135613034653
#      batches:
# ................
#    step 16: dcov = 14.747011897967244
#      batches:
# ................
#    step 17: dcov = 16.462309898170467
#      batches:
# ................
#    step 18: dcov = 16.414401049309582
#      batches:
# ................
#    step 19: dcov = 19.016290540340467
#      batches:
# ................
#    step 20: dcov = 20.507030873023613
#      batches:
# ................
#    step 21: dcov = 20.990688215090408
#      batches:
# ................
#    step 22: dcov = 21.813945701622746
#      batches:
# ................
#    step 23: dcov = 23.68734150011718
#      batches:
# ................
#    step 24: dcov = 25.3677799519596
#      batches:
# ................
#    step 25: dcov = 26.497263934583298
#      batches:
# ................
#    step 26: dcov = 26.485277754990264
#      batches:
# ................
#    step 27: dcov = 28.013886261977802
#      batches:
# ................
#    step 28: dcov = 29.15103066848924
#      batches:
# ................
#    step 29: dcov = 29.382060288894756
#      batches:
# ................
#    step 30: dcov = 30.800260341131608
#      batches:
# ................
#
# dca dimension 13
#    step 1: dcov = 2.1044843123687462
#      batches:
# ................
#    step 2: dcov = 7.441787158903561
#      batches:
# ................
#    step 3: dcov = 6.517205306528612
#      batches:
# ................
#    step 4: dcov = 7.260277606357628
#      batches:
# ................
#    step 5: dcov = 3.8124240698035385
#      batches:
# ................
#    step 6: dcov = 6.017538494568863
#      batches:
# ................
#    step 7: dcov = 7.618669106041125
#      batches:
# ................
#    step 8: dcov = 5.4408561502487105
#      batches:
# ................
#    step 9: dcov = 7.471115887700995
#      batches:
# ................
#    step 10: dcov = 7.332531134878483
#      batches:
# ................
#    step 11: dcov = 8.737944099253237
#      batches:
# ................
#    step 12: dcov = 5.780269569638307
#      batches:
# ................
#    step 13: dcov = 8.197755395707027
#      batches:
# ................
#    step 14: dcov = 8.726456241601392
#      batches:
# ................
#    step 15: dcov = 8.904818416167988
#      batches:
# ................
#    step 16: dcov = 7.695692457158431
#      batches:
# ................
#    step 17: dcov = 11.320656938715473
#      batches:
# ................
#    step 18: dcov = 13.967406894511184
#      batches:
# ................
#    step 19: dcov = 16.638782506255016
#      batches:
# ................
#    step 20: dcov = 16.30247334441378
#      batches:
# ................
#    step 21: dcov = 15.335685820707596
#      batches:
# ................
#    step 22: dcov = 19.83570359960785
#      batches:
# ................
#    step 23: dcov = 21.27707982585562
#      batches:
# ................
#    step 24: dcov = 21.083747642907763
#      batches:
# ................
#    step 25: dcov = 23.355175183935355
#      batches:
# ................
#    step 26: dcov = 22.779360806468077
#      batches:
# ................
#    step 27: dcov = 24.700852637447884
#      batches:
# ................
#    step 28: dcov = 26.11964288011696
#      batches:
# ................
#    step 29: dcov = 25.881364761506717
#      batches:
# ................
#    step 30: dcov = 27.555230339929732
#      batches:
# ................
#
# dca dimension 14
#    step 1: dcov = 1.8360252501395744
#      batches:
# ................
#    step 2: dcov = 7.424568904806371
#      batches:
# ................
#    step 3: dcov = 4.499315403389319
#      batches:
# ................
#    step 4: dcov = 9.18269390465396
#      batches:
# ................
#    step 5: dcov = 5.414572681472031
#      batches:
# ................
#    step 6: dcov = 5.4393809875706
#      batches:
# ................
#    step 7: dcov = 5.89343640007986
#      batches:
# ................
#    step 8: dcov = 5.321177209471227
#      batches:
# ................
#    step 9: dcov = 6.148534591734744
#      batches:
# ................
#    step 10: dcov = 5.899849017024644
#      batches:
# ................
#    step 11: dcov = 8.199972384781697
#      batches:
# ................
#    step 12: dcov = 7.468941792463856
#      batches:
# ................
#    step 13: dcov = 7.78477015232705
#      batches:
# ................
#    step 14: dcov = 5.402207438653387
#      batches:
# ................
#    step 15: dcov = 9.046213900886405
#      batches:
# ................
#    step 16: dcov = 11.703620019692046
#      batches:
# ................
#    step 17: dcov = 9.824284992855418
#      batches:
# ................
#    step 18: dcov = 12.875323694731943
#      batches:
# ................
#    step 19: dcov = 15.005812127327557
#      batches:
# ................
#    step 20: dcov = 13.39709112704454
#      batches:
# ................
#    step 21: dcov = 16.873458395634586
#      batches:
# ................
#    step 22: dcov = 16.733339099003363
#      batches:
# ................
#    step 23: dcov = 17.837216463758132
#      batches:
# ................
#    step 24: dcov = 18.968790924327525
#      batches:
# ................
#    step 25: dcov = 19.15015005274822
#      batches:
# ................
#    step 26: dcov = 21.933894554555938
#      batches:
# ................
#    step 27: dcov = 22.657680390449936
#      batches:
# ................
#    step 28: dcov = 23.456320826132707
#      batches:
# ................
#    step 29: dcov = 23.038852870919865
#      batches:
# ................
#    step 30: dcov = 25.945369706666096
#      batches:
# ................
#
# dca dimension 15
#    step 1: dcov = 2.301581769272764
#      batches:
# ................
#    step 2: dcov = 8.047787961412928
#      batches:
# ................
#    step 3: dcov = 7.910547629174286
#      batches:
# ................
#    step 4: dcov = 6.94531399543247
#      batches:
# ................
#    step 5: dcov = 6.290697112745071
#      batches:
# ................
#    step 6: dcov = 5.781324881622281
#      batches:
# ................
#    step 7: dcov = 5.924557545391853
#      batches:
# ................
#    step 8: dcov = 6.827676577531216
#      batches:
# ................
#    step 9: dcov = 4.289082123453933
#      batches:
# ................
#    step 10: dcov = 6.243880324714846
#      batches:
# ................
#    step 11: dcov = 6.635276587905016
#      batches:
# ................
#    step 12: dcov = 9.469676892224975
#      batches:
# ................
#    step 13: dcov = 6.1651137679891965
#      batches:
# ................
#    step 14: dcov = 4.973344778655559
#      batches:
# ................
#    step 15: dcov = 7.979989299460507
#      batches:
# ................
#    step 16: dcov = 7.00298252360432
#      batches:
# ................
#    step 17: dcov = 8.066576814823058
#      batches:
# ................
#    step 18: dcov = 9.711253710084456
#      batches:
# ................
#    step 19: dcov = 10.50301977966392
#      batches:
# ................
#    step 20: dcov = 10.830009114903975
#      batches:
# ................
#    step 21: dcov = 11.451484159690175
#      batches:
# ................
#    step 22: dcov = 12.297790927060438
#      batches:
# ................
#    step 23: dcov = 12.219785402015253
#      batches:
# ................
#    step 24: dcov = 11.771409581856167
#      batches:
# ................
#    step 25: dcov = 12.830765269524026
#      batches:
# ................
#    step 26: dcov = 15.18716127756337
#      batches:
# ................
#    step 27: dcov = 16.25032089791776
#      batches:
# ................
#    step 28: dcov = 16.69865338532902
#      batches:
# ................
#    step 29: dcov = 18.976503510957837
#      batches:
# ................
#    step 30: dcov = 22.528101304000078
#      batches:
# ................

# %%
# get outputs 
hvg_U = hvg_U_list[0]  # cells x k
hvg_Z = (X_hvg_array.T @ hvg_U)  # genes x k

# %%
# look at outputs
print("HVG U shape (cells x k):", hvg_U.shape)
print("HVG Z shape (genes x k):", hvg_Z.shape)
print("HVG distance covariances shape (k,):", hvg_dcovs.shape)
# Out:
# HVG U shape (cells x k): (16112, 15)
# HVG Z shape (genes x k): (1640, 15)
# HVG distance covariances shape (k,): (1, 15)

# %%
# save to CSV files with labels
k_actual = hvg_U.shape[1]
cols = [f"DCA_dim_{i+1}" for i in range(k_actual)]

hvg_U_df = pd.DataFrame(hvg_U, index=hvg_gene_names, columns=cols) # loadings (genes x k)
hvg_U_df.to_csv("/Users/emilyekstrum/repos/zhangLab_Rotation/data/processed/DCA/mouse_hvg_DCA_U.csv")

hvg_Z_df = pd.DataFrame(hvg_Z, index=hvg_cell_ids, columns=cols) # scores (cells x k)
hvg_Z_df.to_csv("/Users/emilyekstrum/repos/zhangLab_Rotation/data/processed/DCA/mouse_hvg_DCA_Z.csv")

hvg_dcovs = np.asarray(hvg_dcovs).reshape(-1)
dc_df = pd.DataFrame({"dimension": [f"DCA{i+1}" for i in range(len(hvg_dcovs))], "distance_covariance": hvg_dcovs})
dc_df.to_csv("/Users/emilyekstrum/repos/zhangLab_Rotation/data/processed/DCA/mouse_hvg_DCA_distance_covariance.csv", index=False)

# %%
# save items
np.save("/Users/emilyekstrum/repos/zhangLab_Rotation/data/processed/DCA/mouse_hvg_U_DCA.npy", hvg_U) # gene loadings
np.save("/Users/emilyekstrum/repos/zhangLab_Rotation/data/processed/DCA/mouse_hvg_Z_DCA.npy", hvg_Z) # cell embeddings
np.save("/Users/emilyekstrum/repos/zhangLab_Rotation/data/processed/DCA/mouse_hvg_dcovs_DCA.npy", hvg_dcovs) # distance covariances per DCA dim

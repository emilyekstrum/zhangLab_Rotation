# %% [markdown]
# # Distance Covariance Analysis (DCA) for mouse COMMOT results
#
# - X = SVG or HVG expression matrix
# - Y = spatial coords
#
# author: @emilyekstrum
# 1/26/26

# %%
from dca import dca
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import rpy2.robjects as ro
from rpy2.robjects import pandas2ri
import anndata
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import pdist, squareform

# %%
# load in mouse seurat object
ro.r('library(Seurat)')
ro.r('obj <- readRDS("/Users/emilyekstrum/repos/zhangLab_Rotation/data/processed/seurat_objs/mousebrain_seurat.rds")')
# Out:
# R callback write-console: Loading required package: SeuratObject
#
# R callback write-console: Loading required package: sp
#
# R callback write-console:
# Attaching package: ‘SeuratObject’
#
#
# R callback write-console: The following objects are masked from ‘package:base’:
#
#     intersect, t
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.

# %%
# get mouse seurat obj coordinates
coords = ro.r('''
md <- obj@meta.data
md[, c("imagecol","imagerow")]
''')
coords = pandas2ri.rpy2py(coords)
coords.index = coords.index.astype(str)
coords.columns = ["x", "y"]  


print(coords.head()) # cell ID by location
# Out:
#                          x       y
# AAACAAGTATCTCCCA-1  7410.0  8455.0
# AAACAGAGCGACTCCT-1  3097.0  7905.0
# AAACAGGGTCTATATT-1  7050.0  2327.0
# AAACATTTCCCGGATT-1  8728.0  8111.0
# AAACCCGAACGAAATC-1  6811.0  9351.0

# %%
# load in mouse svgs
mouse_svgs = anndata.read_h5ad("/Users/emilyekstrum/repos/zhangLab_Rotation/data/processed/COMMOT/mouse_svg_lr_sets/mouse_commot_LR_svg.h5ad")

# %%
# get counts matrix for svgs
svgs_counts = mouse_svgs.X.copy()
if isinstance(svgs_counts, np.ndarray):
    svgs_counts = svgs_counts
else:
    svgs_counts = svgs_counts.toarray()
svgs_counts = pd.DataFrame(svgs_counts, index=mouse_svgs.obs_names, columns=mouse_svgs.var_names)
svgs_counts.index = svgs_counts.index.astype(str)

# %%
# check matrix
print(svgs_counts.head())  # cell ID by gene expression
# Out:
#                     Xkr4  Sox17    Mrpl15  Lypla1     Tcea1     Rgs20  \
# AAACAAGTATCTCCCA-1   0.0    0.0  0.000000     0.0  0.000000  0.000000
# AAACAGAGCGACTCCT-1   0.0    0.0  0.693147     0.0  0.693147  0.000000
# AAACAGGGTCTATATT-1   0.0    0.0  0.693147     0.0  0.000000  0.693147
# AAACATTTCCCGGATT-1   0.0    0.0  0.000000     0.0  1.098612  0.000000
# AAACCCGAACGAAATC-1   0.0    0.0  0.000000     0.0  0.000000  0.000000
#
#                      Atp6v1h  Oprk1  Npbwr1    Rb1cc1  ...    mt-Nd4  \
# AAACAAGTATCTCCCA-1  0.000000    0.0     0.0  0.000000  ...  4.553877
# AAACAGAGCGACTCCT-1  0.693147    0.0     0.0  0.693147  ...  5.056246
# AAACAGGGTCTATATT-1  0.693147    0.0     0.0  0.693147  ...  4.787492
# AAACATTTCCCGGATT-1  0.000000    0.0     0.0  0.000000  ...  4.499810
# AAACCCGAACGAAATC-1  0.000000    0.0     0.0  0.693147  ...  4.317488
#
#                       mt-Nd5    mt-Nd6   mt-Cytb     Vamp7     Spry3  Tmlhe  \
# AAACAAGTATCTCCCA-1  2.302585  0.000000  4.852030  0.000000  0.000000    0.0
# AAACAGAGCGACTCCT-1  2.995732  0.693147  5.129899  0.693147  0.693147    0.0
# AAACAGGGTCTATATT-1  2.079442  0.693147  4.897840  0.000000  0.000000    0.0
# AAACATTTCCCGGATT-1  2.197225  1.098612  4.595120  0.000000  0.000000    0.0
# AAACCCGAACGAAATC-1  2.397895  0.000000  4.564348  1.098612  0.000000    0.0
#
#                     AC149090.1  CAAA01118383.1  CAAA01147332.1
# AAACAAGTATCTCCCA-1    0.000000             0.0             0.0
# AAACAGAGCGACTCCT-1    0.693147             0.0             0.0
# AAACAGGGTCTATATT-1    0.693147             0.0             0.0
# AAACATTTCCCGGATT-1    0.000000             0.0             0.0
# AAACCCGAACGAAATC-1    0.693147             0.0             0.0
#
# [5 rows x 16112 columns]

# %%
# align coords and counts matrix
common_cells = svgs_counts.index.intersection(coords.index)
svgs_counts = svgs_counts.loc[common_cells]
svg_coords = coords.loc[common_cells]

# %%
# check that indices match
assert all(svgs_counts.index == svg_coords.index), "Indices do not match!"

# %%
# load im mouse hvgs
mouse_hvgs = anndata.read_h5ad("/Users/emilyekstrum/repos/zhangLab_Rotation/data/processed/COMMOT/mouse_hvg_lr_sets/mouse_commot_LR_hvg.h5ad")

# %%
# get counts matrix for hvgs
hvgs_counts = mouse_hvgs.X.copy()
if isinstance(hvgs_counts, np.ndarray):
    hvgs_counts = hvgs_counts
else:
    hvgs_counts = hvgs_counts.toarray()
hvgs_counts = pd.DataFrame(hvgs_counts, index=mouse_hvgs.obs_names, columns=mouse_hvgs.var_names)
hvgs_counts.index = hvgs_counts.index.astype(str)

# %%
# check matrix
print(hvgs_counts.head())  # cell ID by gene expression
# Out:
#                     Xkr4  Sox17    Mrpl15  Lypla1     Tcea1     Rgs20  \
# AAACAAGTATCTCCCA-1   0.0    0.0  0.000000     0.0  0.000000  0.000000
# AAACAGAGCGACTCCT-1   0.0    0.0  0.693147     0.0  0.693147  0.000000
# AAACAGGGTCTATATT-1   0.0    0.0  0.693147     0.0  0.000000  0.693147
# AAACATTTCCCGGATT-1   0.0    0.0  0.000000     0.0  1.098612  0.000000
# AAACCCGAACGAAATC-1   0.0    0.0  0.000000     0.0  0.000000  0.000000
#
#                      Atp6v1h  Oprk1  Npbwr1    Rb1cc1  ...    mt-Nd4  \
# AAACAAGTATCTCCCA-1  0.000000    0.0     0.0  0.000000  ...  4.553877
# AAACAGAGCGACTCCT-1  0.693147    0.0     0.0  0.693147  ...  5.056246
# AAACAGGGTCTATATT-1  0.693147    0.0     0.0  0.693147  ...  4.787492
# AAACATTTCCCGGATT-1  0.000000    0.0     0.0  0.000000  ...  4.499810
# AAACCCGAACGAAATC-1  0.000000    0.0     0.0  0.693147  ...  4.317488
#
#                       mt-Nd5    mt-Nd6   mt-Cytb     Vamp7     Spry3  Tmlhe  \
# AAACAAGTATCTCCCA-1  2.302585  0.000000  4.852030  0.000000  0.000000    0.0
# AAACAGAGCGACTCCT-1  2.995732  0.693147  5.129899  0.693147  0.693147    0.0
# AAACAGGGTCTATATT-1  2.079442  0.693147  4.897840  0.000000  0.000000    0.0
# AAACATTTCCCGGATT-1  2.197225  1.098612  4.595120  0.000000  0.000000    0.0
# AAACCCGAACGAAATC-1  2.397895  0.000000  4.564348  1.098612  0.000000    0.0
#
#                     AC149090.1  CAAA01118383.1  CAAA01147332.1
# AAACAAGTATCTCCCA-1    0.000000             0.0             0.0
# AAACAGAGCGACTCCT-1    0.693147             0.0             0.0
# AAACAGGGTCTATATT-1    0.693147             0.0             0.0
# AAACATTTCCCGGATT-1    0.000000             0.0             0.0
# AAACCCGAACGAAATC-1    0.693147             0.0             0.0
#
# [5 rows x 16112 columns]

# %%
# align coords and counts matrix
hvg_common_cells = hvgs_counts.index.intersection(coords.index)
hvgs_counts = hvgs_counts.loc[hvg_common_cells]
hvg_coords = coords.loc[hvg_common_cells]

# %%
# check that indices match
assert all(hvgs_counts.index == hvg_coords.index), "Indices do not match!"

# %%
# inputs for DCA 
# need X -> standardized (z scored) gene x cell matrix

scaler = StandardScaler()
X_svg = pd.DataFrame(scaler.fit_transform(svgs_counts), index=svgs_counts.index, columns=svgs_counts.columns)
X_hvg = pd.DataFrame(scaler.fit_transform(hvgs_counts), index=hvgs_counts.index, columns=hvgs_counts.columns)

# %%
# transpose matrices to get gene x cell
X_svg = X_svg.T
X_hvg = X_hvg.T

X_svg.head()
# Out:
#         AAACAAGTATCTCCCA-1  AAACAGAGCGACTCCT-1  AAACAGGGTCTATATT-1  \
# Xkr4              0.000000            0.000000            0.000000
# Sox17            -0.319774           -0.319774           -0.319774
# Mrpl15           -0.734810            0.869913            0.869913
# Lypla1           -0.575309           -0.575309           -0.575309
# Tcea1            -0.812530            0.716311           -0.812530
#
#         AAACATTTCCCGGATT-1  AAACCCGAACGAAATC-1  AAACCGGAAATGTTAA-1  \
# Xkr4              0.000000            0.000000            0.000000
# Sox17            -0.319774           -0.319774            2.737599
# Mrpl15           -0.734810           -0.734810            0.869913
# Lypla1           -0.575309           -0.575309           -0.575309
# Tcea1             1.610626           -0.812530           -0.812530
#
#         AAACCGGGTAGGTACC-1  AAACGAGACGGTTGAT-1  AAACTGCTGGCTCCAA-1  \
# Xkr4              0.000000            0.000000            0.000000
# Sox17            -0.319774           -0.319774           -0.319774
# Mrpl15           -0.734810            0.869913           -0.734810
# Lypla1           -0.575309            1.353987           -0.575309
# Tcea1             0.716311            0.716311           -0.812530
#
#         AAACTTGCAAACGTAT-1  ...  TTGTGAGGCATGACGC-1  TTGTGCAGCCACGTCA-1  \
# Xkr4              0.000000  ...            0.000000            0.000000
# Sox17            -0.319774  ...           -0.319774           -0.319774
# Mrpl15           -0.734810  ...            0.869913           -0.734810
# Lypla1           -0.575309  ...            1.353987           -0.575309
# Tcea1            -0.812530  ...           -0.812530           -0.812530
#
#         TTGTGGCCCTGACAGT-1  TTGTGTATGCCACCAA-1  TTGTGTTTCCCGAAAG-1  \
# Xkr4              0.000000            0.000000            0.000000
# Sox17            -0.319774           -0.319774           -0.319774
# Mrpl15           -0.734810           -0.734810           -0.734810
# Lypla1           -0.575309           -0.575309           -0.575309
# Tcea1             0.716311           -0.812530           -0.812530
#
#         TTGTTAGCAAATTCGA-1  TTGTTCAGTGTGCTAC-1  TTGTTGTGTGTCAAGA-1  \
# Xkr4              0.000000            0.000000            0.000000
# Sox17            -0.319774           -0.319774           -0.319774
# Mrpl15            0.869913           -0.734810            0.869913
# Lypla1            1.353987           -0.575309            1.353987
# Tcea1             0.716311            0.716311           -0.812530
#
#         TTGTTTCATTAGTCTA-1  TTGTTTCCATACAACT-1
# Xkr4              0.000000            0.000000
# Sox17            -0.319774           -0.319774
# Mrpl15           -0.734810            0.869913
# Lypla1           -0.575309           -0.575309
# Tcea1             1.610626            1.610626
#
# [5 rows x 1640 columns]

# %%
# convert gene by cell matrices to arrays
X_svg_array = X_svg.values
X_hvg_array = X_hvg.values

# %%
X_svg_array
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.31977388, -0.31977388, -0.31977388, ..., -0.31977388,
#         -0.31977388, -0.31977388],
#        [-0.73481012,  0.8699128 ,  0.8699128 , ...,  0.8699128 ,
#         -0.73481012,  0.8699128 ],
#        ...,
#        [-1.24452374, -0.09148907, -0.09148907, ...,  1.06154561,
#         -0.09148907, -0.09148907],
#        [-0.37689703, -0.37689703, -0.37689703, ..., -0.37689703,
#         -0.37689703, -0.37689703],
#        [-0.10234466, -0.10234466, -0.10234466, ..., -0.10234466,
#         -0.10234466, -0.10234466]], shape=(16112, 1640))

# %%
# dependent distance matrix from coordinates (cells x cells)

dist_matrix = squareform(pdist(svg_coords.values, metric='euclidean'))
#dist_matrix = pd.DataFrame(dist_matrix, index=svg_coords.index, columns=svg_coords.index)

# %%
dist_matrix
# Out:
# array([[   0.        , 4347.92697731, 6138.56530469, ..., 2854.21968321,
#         5099.71107025, 5198.62452962],
#        [4347.92697731,    0.        , 6836.6872826 , ..., 2348.73093393,
#         7056.3992234 , 5923.07285115],
#        [6138.56530469, 6836.6872826 ,    0.        , ..., 4805.88576643,
#         1949.00102617,  993.18527979],
#        ...,
#        [2854.21968321, 2348.73093393, 4805.88576643, ...,    0.        ,
#         4748.40194171, 3830.13485402],
#        [5099.71107025, 7056.3992234 , 1949.00102617, ..., 4748.40194171,
#            0.        , 1808.8830808 ],
#        [5198.62452962, 5923.07285115,  993.18527979, ..., 3830.13485402,
#         1808.8830808 ,    0.        ]], shape=(1640, 1640))

# %%
# DCA parameters
k = 15 # number of dims

# %%
# run DCA for SVGs

svg_U_list, svg_dcovs = dca(
    Xs=[X_svg_array],               # list of datasets to project (genes x cells)
    Ds=[dist_matrix],               # list of dependent distance matrices (cells x cells)
    num_dca_dimensions=k,           # number of DCA dimensions to learn
    num_iters_per_dataset=1,        # number of times to run DCA per dataset, default 1
    num_iters_foreach_dim=30,       # number of iterations to run for each dimension, default 30
    num_stoch_batch_samples=100,    # number of cells to use in stochastic batches when estimating gradients, default 100
    num_samples_to_compute_stepwise_dcov=1000, # number of samples to use when computing distance covariance, default 1000
    percent_increase_criterion=0.01 # convergence criterion, default 0.01
)
# Out:
# dca dimension 1
#    step 1: dcov = 3.9832745582685694
#      batches:
# ................
#    step 2: dcov = 65.16871748277676
#      batches:
# ................
#    step 3: dcov = 75.6528686969988
#      batches:
# ................
#    step 4: dcov = 65.29375698016224
#      batches:
# ................
#    step 5: dcov = 81.22455809925835
#      batches:
# ................
#    step 6: dcov = 83.38422241755038
#      batches:
# ................
#    step 7: dcov = 80.42404378625741
#      batches:
# ................
#    step 8: dcov = 82.3290576310698
#      batches:
# ................
#    step 9: dcov = 84.45226525669729
#      batches:
# ................
#    step 10: dcov = 87.03867446451189
#      batches:
# ................
#    step 11: dcov = 91.14038286708497
#      batches:
# ................
#    step 12: dcov = 87.74680718661202
#      batches:
# ................
#    step 13: dcov = 86.14837627799318
#      batches:
# ................
#    step 14: dcov = 88.21368595151864
#      batches:
# ................
#    step 15: dcov = 91.18770366822066
#      batches:
# ................
#    step 16: dcov = 87.39067713055664
#      batches:
# ................
#    step 17: dcov = 88.14963093149416
#      batches:
# ................
#    step 18: dcov = 89.68035911960477
#      batches:
# ................
#    step 19: dcov = 93.36117429475681
#      batches:
# ................
#    step 20: dcov = 94.69181967458339
#      batches:
# ................
#    step 21: dcov = 92.39303685546955
#      batches:
# ................
#    step 22: dcov = 92.42826374234967
#      batches:
# ................
#    step 23: dcov = 92.64847990270088
#      batches:
# ................
#    step 24: dcov = 92.79666311366735
#      batches:
# ................
#    step 25: dcov = 92.32728941765625
#      batches:
# ................
#    step 26: dcov = 93.7102620109092
#      batches:
# ................
#    step 27: dcov = 93.43992455290346
#      batches:
# ................
#    step 28: dcov = 91.71422989573036
#      batches:
# ................
#    step 29: dcov = 92.49802186443073
#      batches:
# ................
#    step 30: dcov = 92.14316899584274
#      batches:
# ................
#
# dca dimension 2
#    step 1: dcov = 2.2379636259446323
#      batches:
# ................
#    step 2: dcov = 52.133444736131516
#      batches:
# ................
#    step 3: dcov = 54.11857467998593
#      batches:
# ................
#    step 4: dcov = 52.59351671021082
#      batches:
# ................
#    step 5: dcov = 56.576405983304056
#      batches:
# ................
#    step 6: dcov = 57.59889225822627
#      batches:
# ................
#    step 7: dcov = 60.25409792249484
#      batches:
# ................
#    step 8: dcov = 58.75894108703614
#      batches:
# ................
#    step 9: dcov = 57.54098120796229
#      batches:
# ................
#    step 10: dcov = 64.85851062114727
#      batches:
# ................
#    step 11: dcov = 64.95595610311129
#      batches:
# ................
#    step 12: dcov = 62.37797813031211
#      batches:
# ................
#    step 13: dcov = 64.60678380249688
#      batches:
# ................
#    step 14: dcov = 67.25878494876073
#      batches:
# ................
#    step 15: dcov = 64.20051545189767
#      batches:
# ................
#    step 16: dcov = 66.90867900478429
#      batches:
# ................
#    step 17: dcov = 65.82690567057816
#      batches:
# ................
#    step 18: dcov = 67.6854006668554
#      batches:
# ................
#    step 19: dcov = 66.28060402909885
#      batches:
# ................
#    step 20: dcov = 68.65012578252646
#      batches:
# ................
#    step 21: dcov = 67.11112809784267
#      batches:
# ................
#    step 22: dcov = 69.99822271980521
#      batches:
# ................
#    step 23: dcov = 70.09461298268565
#      batches:
# ................
#    step 24: dcov = 69.32224273525547
#      batches:
# ................
#    step 25: dcov = 69.0297874440383
#      batches:
# ................
#    step 26: dcov = 70.96262146529871
#      batches:
# ................
#    step 27: dcov = 68.69809079686368
#      batches:
# ................
#    step 28: dcov = 70.34553270253251
#      batches:
# ................
#    step 29: dcov = 69.95322290645535
#      batches:
# ................
#    step 30: dcov = 69.97476408887776
#      batches:
# ................
#
# dca dimension 3
#    step 1: dcov = 2.276547798971706
#      batches:
# ................
#    step 2: dcov = 35.53018746095492
#      batches:
# ................
#    step 3: dcov = 37.959152709866636
#      batches:
# ................
#    step 4: dcov = 37.85136345871166
#      batches:
# ................
#    step 5: dcov = 39.575910477163774
#      batches:
# ................
#    step 6: dcov = 43.132035405132655
#      batches:
# ................
#    step 7: dcov = 42.636222581294284
#      batches:
# ................
#    step 8: dcov = 45.70082743290577
#      batches:
# ................
#    step 9: dcov = 46.717067247855674
#      batches:
# ................
#    step 10: dcov = 46.56867693763176
#      batches:
# ................
#    step 11: dcov = 47.31184875490495
#      batches:
# ................
#    step 12: dcov = 46.91732466897918
#      batches:
# ................
#    step 13: dcov = 48.548676902351836
#      batches:
# ................
#    step 14: dcov = 48.776728416796686
#      batches:
# ................
#    step 15: dcov = 49.475521923073366
#      batches:
# ................
#    step 16: dcov = 49.414217104874
#      batches:
# ................
#    step 17: dcov = 51.797919428405635
#      batches:
# ................
#    step 18: dcov = 49.669159935360675
#      batches:
# ................
#    step 19: dcov = 50.63026343222199
#      batches:
# ................
#    step 20: dcov = 48.969504954256315
#      batches:
# ................
#    step 21: dcov = 50.98305007740406
#      batches:
# ................
#    step 22: dcov = 50.5016915173248
#      batches:
# ................
#    step 23: dcov = 51.20995581507992
#      batches:
# ................
#    step 24: dcov = 53.751527061018116
#      batches:
# ................
#    step 25: dcov = 50.388561496827954
#      batches:
# ................
#    step 26: dcov = 50.22225717808053
#      batches:
# ................
#    step 27: dcov = 51.14606518709999
#      batches:
# ................
#    step 28: dcov = 50.919828210890536
#      batches:
# ................
#    step 29: dcov = 51.22095191847355
#      batches:
# ................
#    step 30: dcov = 53.37054265368806
#      batches:
# ................
#
# dca dimension 4
#    step 1: dcov = 1.9179317911391196
#      batches:
# ................
#    step 2: dcov = 10.957556340541512
#      batches:
# ................
#    step 3: dcov = 10.539907227907893
#      batches:
# ................
#    step 4: dcov = 15.296360848109666
#      batches:
# ................
#    step 5: dcov = 10.918739652780861
#      batches:
# ................
#    step 6: dcov = 13.952857425938085
#      batches:
# ................
#    step 7: dcov = 10.608095464600934
#      batches:
# ................
#    step 8: dcov = 16.10048279082108
#      batches:
# ................
#    step 9: dcov = 19.27345260920803
#      batches:
# ................
#    step 10: dcov = 19.782357238372775
#      batches:
# ................
#    step 11: dcov = 19.96209262462879
#      batches:
# ................
#    step 12: dcov = 20.90639207263972
#      batches:
# ................
#    step 13: dcov = 23.330713485376823
#      batches:
# ................
#    step 14: dcov = 27.742842609057746
#      batches:
# ................
#    step 15: dcov = 25.4917915551905
#      batches:
# ................
#    step 16: dcov = 26.18494450289574
#      batches:
# ................
#    step 17: dcov = 26.81795304369233
#      batches:
# ................
#    step 18: dcov = 27.175555793297228
#      batches:
# ................
#    step 19: dcov = 29.02860019857383
#      batches:
# ................
#    step 20: dcov = 31.897936146722714
#      batches:
# ................
#    step 21: dcov = 31.621018936085637
#      batches:
# ................
#    step 22: dcov = 31.9796531561305
#      batches:
# ................
#    step 23: dcov = 32.582902696404304
#      batches:
# ................
#    step 24: dcov = 32.992527508213655
#      batches:
# ................
#    step 25: dcov = 33.58332187929463
#      batches:
# ................
#    step 26: dcov = 38.28324262901239
#      batches:
# ................
#    step 27: dcov = 36.882963332773734
#      batches:
# ................
#    step 28: dcov = 35.47439257331414
#      batches:
# ................
#    step 29: dcov = 37.462702038129606
#      batches:
# ................
#    step 30: dcov = 37.37515368464273
#      batches:
# ................
#
# dca dimension 5
#    step 1: dcov = 2.1736018852028915
#      batches:
# ................
#    step 2: dcov = 10.333224458370147
#      batches:
# ................
#    step 3: dcov = 10.88094706639004
#      batches:
# ................
#    step 4: dcov = 13.065287761659881
#      batches:
# ................
#    step 5: dcov = 14.334384080992393
#      batches:
# ................
#    step 6: dcov = 13.916387804924424
#      batches:
# ................
#    step 7: dcov = 16.31026545469965
#      batches:
# ................
#    step 8: dcov = 20.991780393057443
#      batches:
# ................
#    step 9: dcov = 19.854503114126235
#      batches:
# ................
#    step 10: dcov = 17.757187001552552
#      batches:
# ................
#    step 11: dcov = 19.98455347798776
#      batches:
# ................
#    step 12: dcov = 20.8589475182668
#      batches:
# ................
#    step 13: dcov = 23.40701303480911
#      batches:
# ................
#    step 14: dcov = 24.00641610386567
#      batches:
# ................
#    step 15: dcov = 23.621387415325795
#      batches:
# ................
#    step 16: dcov = 25.43516544462039
#      batches:
# ................
#    step 17: dcov = 26.034079621668276
#      batches:
# ................
#    step 18: dcov = 27.775143954737473
#      batches:
# ................
#    step 19: dcov = 30.52662162312678
#      batches:
# ................
#    step 20: dcov = 28.724459032590826
#      batches:
# ................
#    step 21: dcov = 30.215147701182524
#      batches:
# ................
#    step 22: dcov = 30.4439454681218
#      batches:
# ................
#    step 23: dcov = 32.78332148219491
#      batches:
# ................
#    step 24: dcov = 32.17933732047008
#      batches:
# ................
#    step 25: dcov = 35.36457041926586
#      batches:
# ................
#    step 26: dcov = 33.77479681042219
#      batches:
# ................
#    step 27: dcov = 34.58109568174618
#      batches:
# ................
#    step 28: dcov = 36.296461535173755
#      batches:
# ................
#    step 29: dcov = 36.23389781965136
#      batches:
# ................
#    step 30: dcov = 36.04789714806026
#      batches:
# ................
#
# dca dimension 6
#    step 1: dcov = 2.0184962352004585
#      batches:
# ................
#    step 2: dcov = 9.196902634260947
#      batches:
# ................
#    step 3: dcov = 9.984646827046834
#      batches:
# ................
#    step 4: dcov = 8.039395970417871
#      batches:
# ................
#    step 5: dcov = 7.353942250408562
#      batches:
# ................
#    step 6: dcov = 10.129220773443242
#      batches:
# ................
#    step 7: dcov = 11.485681463920784
#      batches:
# ................
#    step 8: dcov = 16.239034348950696
#      batches:
# ................
#    step 9: dcov = 16.754689694297177
#      batches:
# ................
#    step 10: dcov = 15.912182424848961
#      batches:
# ................
#    step 11: dcov = 16.343629685528082
#      batches:
# ................
#    step 12: dcov = 17.5958653706133
#      batches:
# ................
#    step 13: dcov = 16.565874803441854
#      batches:
# ................
#    step 14: dcov = 21.767251344384835
#      batches:
# ................
#    step 15: dcov = 21.111207535495645
#      batches:
# ................
#    step 16: dcov = 23.273032870028633
#      batches:
# ................
#    step 17: dcov = 26.891992074182927
#      batches:
# ................
#    step 18: dcov = 27.458815795053397
#      batches:
# ................
#    step 19: dcov = 28.062405870128995
#      batches:
# ................
#    step 20: dcov = 28.94420539110362
#      batches:
# ................
#    step 21: dcov = 29.834096142840586
#      batches:
# ................
#    step 22: dcov = 29.08496844881187
#      batches:
# ................
#    step 23: dcov = 30.967109078451944
#      batches:
# ................
#    step 24: dcov = 31.166444045466726
#      batches:
# ................
#    step 25: dcov = 31.95887941216415
#      batches:
# ................
#    step 26: dcov = 33.0716342587332
#      batches:
# ................
#    step 27: dcov = 35.58118527019752
#      batches:
# ................
#    step 28: dcov = 33.23320799276606
#      batches:
# ................
#    step 29: dcov = 35.79333296049684
#      batches:
# ................
#    step 30: dcov = 35.412603251071104
#      batches:
# ................
#
# dca dimension 7
#    step 1: dcov = 1.8816025036421755
#      batches:
# ................
#    step 2: dcov = 10.302671057310322
#      batches:
# ................
#    step 3: dcov = 9.239699316866112
#      batches:
# ................
#    step 4: dcov = 10.89013906606288
#      batches:
# ................
#    step 5: dcov = 11.276815820463264
#      batches:
# ................
#    step 6: dcov = 10.215848323436878
#      batches:
# ................
#    step 7: dcov = 12.161710944504517
#      batches:
# ................
#    step 8: dcov = 10.443474597237579
#      batches:
# ................
#    step 9: dcov = 11.514492331982812
#      batches:
# ................
#    step 10: dcov = 13.876733334253304
#      batches:
# ................
#    step 11: dcov = 14.98449403710706
#      batches:
# ................
#    step 12: dcov = 18.338746061443107
#      batches:
# ................
#    step 13: dcov = 20.766911397698497
#      batches:
# ................
#    step 14: dcov = 18.228366019862698
#      batches:
# ................
#    step 15: dcov = 20.959302928038312
#      batches:
# ................
#    step 16: dcov = 21.218616308937904
#      batches:
# ................
#    step 17: dcov = 23.94302453762072
#      batches:
# ................
#    step 18: dcov = 21.478759808472113
#      batches:
# ................
#    step 19: dcov = 24.888212278280772
#      batches:
# ................
#    step 20: dcov = 24.909240629184872
#      batches:
# ................
#    step 21: dcov = 26.280270955722866
#      batches:
# ................
#    step 22: dcov = 27.746251018730856
#      batches:
# ................
#    step 23: dcov = 30.76403394421744
#      batches:
# ................
#    step 24: dcov = 28.991902354935007
#      batches:
# ................
#    step 25: dcov = 31.01083398767365
#      batches:
# ................
#    step 26: dcov = 31.029937119988347
#      batches:
# ................
#    step 27: dcov = 33.122832224698286
#      batches:
# ................
#    step 28: dcov = 32.82614406318105
#      batches:
# ................
#    step 29: dcov = 33.84907235437404
#      batches:
# ................
#    step 30: dcov = 34.26387935927339
#      batches:
# ................
#
# dca dimension 8
#    step 1: dcov = 1.9230557832999964
#      batches:
# ................
#    step 2: dcov = 8.350438445323473
#      batches:
# ................
#    step 3: dcov = 8.851172254266743
#      batches:
# ................
#    step 4: dcov = 9.854269159552727
#      batches:
# ................
#    step 5: dcov = 9.047730744058041
#      batches:
# ................
#    step 6: dcov = 10.045069346837076
#      batches:
# ................
#    step 7: dcov = 11.760517212455762
#      batches:
# ................
#    step 8: dcov = 12.959011680782194
#      batches:
# ................
#    step 9: dcov = 10.952712648860471
#      batches:
# ................
#    step 10: dcov = 14.649835321591176
#      batches:
# ................
#    step 11: dcov = 11.092140207701894
#      batches:
# ................
#    step 12: dcov = 15.130283227440785
#      batches:
# ................
#    step 13: dcov = 12.151587774632574
#      batches:
# ................
#    step 14: dcov = 14.329302228037852
#      batches:
# ................
#    step 15: dcov = 16.985176076586043
#      batches:
# ................
#    step 16: dcov = 16.55839893608184
#      batches:
# ................
#    step 17: dcov = 19.294823469032167
#      batches:
# ................
#    step 18: dcov = 24.079398036389744
#      batches:
# ................
#    step 19: dcov = 23.142251170054113
#      batches:
# ................
#    step 20: dcov = 24.85201722937084
#      batches:
# ................
#    step 21: dcov = 24.9240911038259
#      batches:
# ................
#    step 22: dcov = 27.271204793777194
#      batches:
# ................
#    step 23: dcov = 26.62978398595949
#      batches:
# ................
#    step 24: dcov = 28.613352279516445
#      batches:
# ................
#    step 25: dcov = 30.01745633173717
#      batches:
# ................
#    step 26: dcov = 29.920263906196713
#      batches:
# ................
#    step 27: dcov = 29.89536640494171
#      batches:
# ................
#    step 28: dcov = 32.45026550835084
#      batches:
# ................
#    step 29: dcov = 33.211233252122334
#      batches:
# ................
#    step 30: dcov = 32.7270015378539
#      batches:
# ................
#
# dca dimension 9
#    step 1: dcov = 2.054173276268722
#      batches:
# ................
#    step 2: dcov = 7.40812767669733
#      batches:
# ................
#    step 3: dcov = 8.238056171243533
#      batches:
# ................
#    step 4: dcov = 8.109748051729087
#      batches:
# ................
#    step 5: dcov = 9.132179457643923
#      batches:
# ................
#    step 6: dcov = 8.27011196817457
#      batches:
# ................
#    step 7: dcov = 10.848138350213402
#      batches:
# ................
#    step 8: dcov = 9.154462814927836
#      batches:
# ................
#    step 9: dcov = 13.132287768666721
#      batches:
# ................
#    step 10: dcov = 13.02359024593706
#      batches:
# ................
#    step 11: dcov = 14.484046256605184
#      batches:
# ................
#    step 12: dcov = 14.713988536096823
#      batches:
# ................
#    step 13: dcov = 14.616643344948852
#      batches:
# ................
#    step 14: dcov = 14.833396555938918
#      batches:
# ................
#    step 15: dcov = 16.55008153442553
#      batches:
# ................
#    step 16: dcov = 20.406086939322837
#      batches:
# ................
#    step 17: dcov = 18.526844649856926
#      batches:
# ................
#    step 18: dcov = 17.028031595547574
#      batches:
# ................
#    step 19: dcov = 21.333635861237305
#      batches:
# ................
#    step 20: dcov = 20.24861532125991
#      batches:
# ................
#    step 21: dcov = 21.547864750346204
#      batches:
# ................
#    step 22: dcov = 22.950909929694642
#      batches:
# ................
#    step 23: dcov = 23.055524379389848
#      batches:
# ................
#    step 24: dcov = 24.905468700146173
#      batches:
# ................
#    step 25: dcov = 24.78596851893355
#      batches:
# ................
#    step 26: dcov = 25.85086858616248
#      batches:
# ................
#    step 27: dcov = 27.981977656345826
#      batches:
# ................
#    step 28: dcov = 25.35870426280686
#      batches:
# ................
#    step 29: dcov = 27.372747892825366
#      batches:
# ................
#    step 30: dcov = 28.211215717800165
#      batches:
# ................
#
# dca dimension 10
#    step 1: dcov = 1.9282705520511674
#      batches:
# ................
#    step 2: dcov = 7.857510820235876
#      batches:
# ................
#    step 3: dcov = 8.90105971680428
#      batches:
# ................
#    step 4: dcov = 5.705485296663848
#      batches:
# ................
#    step 5: dcov = 6.967100669820979
#      batches:
# ................
#    step 6: dcov = 5.588393891303627
#      batches:
# ................
#    step 7: dcov = 7.009308037493924
#      batches:
# ................
#    step 8: dcov = 7.7351487942231
#      batches:
# ................
#    step 9: dcov = 5.451776506846232
#      batches:
# ................
#    step 10: dcov = 10.366639799712523
#      batches:
# ................
#    step 11: dcov = 9.629522812186343
#      batches:
# ................
#    step 12: dcov = 9.226037132312472
#      batches:
# ................
#    step 13: dcov = 8.864995230121748
#      batches:
# ................
#    step 14: dcov = 13.844663801810874
#      batches:
# ..........

# %%
# get outputs 
svg_U = svg_U_list[0]  # cells x k
svg_Z = (X_svg_array.T @ svg_U)  # genes x k

# %%
# save to CSV files with labels
k_actual = svg_U.shape[1]
cols = [f"DCA_dim_{i+1}" for i in range(k_actual)]

svg_U_df = pd.DataFrame(svg_U, index=svgs_counts.index, columns=cols) # loadings (genes x k)
svg_U_df.to_csv("/Users/emilyekstrum/repos/zhangLab_Rotation/data/processed/DCA/mouse_svg_DCA_U.csv")

svg_Z_df = pd.DataFrame(svg_Z, index=svgs_counts.columns, columns=cols) # scores (cells x k)
svg_Z_df.to_csv("/Users/emilyekstrum/repos/zhangLab_Rotation/data/processed/DCA/mouse_svg_DCA_Z.csv")

svg_dcovs = np.asarray(svg_dcovs).reshape(-1)
dc_df = pd.DataFrame(("dimension": [f"DCA{i+1}" for i in range(len{svg_dcovs})], "distance_covariance": svg_dcovs))
dc_df.to_csv("/Users/emilyekstrum/repos/zhangLab_Rotation/data/processed/DCA/mouse_svg_DCA_distance_covariance.csv", index=False)

# %%
# save items
np.save("svg_U_DCA.npy", svg_U) # gene loadings
np.save("svg_Z_DCA.npy", svg_Z) # cell embeddings
np.save("svg_dcovs_DCA.npy", dcovs) # distance covariances per DCA dim

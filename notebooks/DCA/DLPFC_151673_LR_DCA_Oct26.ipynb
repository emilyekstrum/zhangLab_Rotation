# %%
import numpy as np
import pandas as pd
from pathlib import Path
from scipy.spatial.distance import pdist, squareform
from dca import dca

# %%
# INPUTS 
# don't have these files
SCT_CSV   = "/Users/emilyekstrum/Desktop/zhangLab/data/DLPFC_Data/Sample151673/Sim3_2454hvgs_matrix.csv"   # rows=genes, cols=cells
COORDS_CSV= "/Users/nanxi/Documents/ZhangLab/Spatial_transcriptomics/Spatial_clusters/Output/Sim3_151673/Sim3_cell_location.csv"    # rows=cells, cols include x,y (or X,Y / row,col)
K = 15                       # number of DCA dimensions to extract

# %%
# standardizes features (z‑score),
def zscore_rows(A):
    """
    Z-score each gene across cells.
    A is (genes x cells). We center/scale row-wise.
    """
    mu = A.mean(axis=1, keepdims=True)
    sd = A.std(axis=1, ddof=1, keepdims=True)
    sd[sd == 0] = 1.0
    return (A - mu) / sd

# %%
# 1) load csvs
sct = pd.read_csv(SCT_CSV, index_col=0)      # (genes x cells)
coords_df = pd.read_csv(COORDS_CSV, index_col=0)

# 2) grab x,y
if {"x","y"}.issubset(coords_df.columns):
    xy = coords_df[["x","y"]].astype(float)
elif {"X","Y"}.issubset(coords_df.columns):
    xy = coords_df[["X","Y"]].astype(float)
else:
    xy = coords_df.iloc[:, :2].astype(float)

# %%
xy.index
# Out:
# Index(['AAACAAGTATCTCCCA-1', 'AAACAATCTACTAGCA-1', 'AAACACCAATAACTGC-1',
#        'AAACAGAGCGACTCCT-1', 'AAACAGCTTTCAGAAG-1', 'AAACAGGGTCTATATT-1',
#        'AAACAGTGTTCCTGGG-1', 'AAACATTTCCCGGATT-1', 'AAACCCGAACGAAATC-1',
#        'AAACCGGGTAGGTACC-1',
#        ...
#        'TTGTGTATGCCACCAA-1', 'TTGTGTTTCCCGAAAG-1', 'TTGTTAGCAAATTCGA-1',
#        'TTGTTCAGTGTGCTAC-1', 'TTGTTGTGTGTCAAGA-1', 'TTGTTTCACATCCAGG-1',
#        'TTGTTTCATTAGTCTA-1', 'TTGTTTCCATACAACT-1', 'TTGTTTGTATTACACG-1',
#        'TTGTTTGTGTAAATTC-1'],
#       dtype='object', length=3611)

# %%
sct.columns
# Out:
# Index(['AAACAAGTATCTCCCA-1', 'AAACAATCTACTAGCA-1', 'AAACACCAATAACTGC-1',
#        'AAACAGAGCGACTCCT-1', 'AAACAGCTTTCAGAAG-1', 'AAACAGGGTCTATATT-1',
#        'AAACAGTGTTCCTGGG-1', 'AAACATTTCCCGGATT-1', 'AAACCCGAACGAAATC-1',
#        'AAACCGGGTAGGTACC-1',
#        ...
#        'TTGTGTATGCCACCAA-1', 'TTGTGTTTCCCGAAAG-1', 'TTGTTAGCAAATTCGA-1',
#        'TTGTTCAGTGTGCTAC-1', 'TTGTTGTGTGTCAAGA-1', 'TTGTTTCACATCCAGG-1',
#        'TTGTTTCATTAGTCTA-1', 'TTGTTTCCATACAACT-1', 'TTGTTTGTATTACACG-1',
#        'TTGTTTGTGTAAATTC-1'],
#       dtype='object', length=3611)

# %%
# 3) align cells
cells = sct.columns.intersection(xy.index)
if len(cells) == 0:
    raise ValueError("No overlapping cell IDs between SCT and coords.")
#sct = sct.loc[cells]
xy  = xy.loc[cells]

# %%
gene_names = sct.index.to_list()
cell_ids   = sct.columns.to_list()

# %%
# 4) build inputs for dca()
#    X must be (genes x cells); then STANDARDIZE (z-score per gene across cells)
X_gc = sct.to_numpy(dtype=float)          # genes x cells
X_gc = zscore_rows(X_gc)                    # standardization step

#    dependent distance matrix from coordinates: (cells x cells)
D_coords = squareform(pdist(xy.to_numpy(dtype=float), metric="euclidean"))

# %%
X_gc[1:5,3608:3611]
# Out:
# array([[ 0.57559585,  0.41838561, -0.52487585],
#        [-0.15203232, -0.00305302, -0.74794951],
#        [ 1.06652056,  0.855888  , -0.1972748 ],
#        [-0.38534272, -0.38534272, -0.38534272]])

# %%
D_coords
# Out:
# array([[  0.        , 312.52509541, 261.75485784, ..., 233.98605801,
#         226.07327453, 280.58423024],
#        [312.52509541,   0.        , 311.00880392, ..., 231.83050434,
#         377.51293566,  32.90441618],
#        [261.75485784, 311.00880392,   0.        , ...,  79.48418109,
#         101.71767168, 297.41063321],
#        ...,
#        [233.98605801, 231.83050434,  79.48418109, ...,   0.        ,
#         157.10789965, 217.95469838],
#        [226.07327453, 377.51293566, 101.71767168, ..., 157.10789965,
#           0.        , 357.20683064],
#        [280.58423024,  32.90441618, 297.41063321, ..., 217.95469838,
#         357.20683064,   0.        ]])

# %%
# 5) run DCA
U_list, dcovs = dca(
    Xs=[X_gc],                 # list of datasets to project (genes x cells)
    Ds=[D_coords],             # list of dependent distance matrices (cells x cells)
    num_dca_dimensions=K,
    num_iters_per_dataset=1,
    num_iters_foreach_dim=30,
    num_stoch_batch_samples=100,
    num_samples_to_compute_stepwise_dcov=1000,
    percent_increase_criterion=0.01
)
# Out:
# dca dimension 1
#    step 1: dcov = 0.9792576886112597
#      batches:
# ....................................
#    step 2: dcov = 14.382052696963436
#      batches:
# ....................................
#    step 3: dcov = 14.723123976332015
#      batches:
# ....................................
#    step 4: dcov = 14.012817165392418
#      batches:
# ....................................
#    step 5: dcov = 14.534091479931611
#      batches:
# ....................................
#    step 6: dcov = 13.124548934605906
#      batches:
# ....................................
#    step 7: dcov = 14.259298599777608
#      batches:
# ....................................
#    step 8: dcov = 15.125225968384552
#      batches:
# ....................................
#    step 9: dcov = 13.353159294634816
#      batches:
# ....................................
#    step 10: dcov = 15.184130585074234
#      batches:
# ....................................
#    step 11: dcov = 15.293092306990394
#      batches:
# ....................................
#    step 12: dcov = 15.604627616524818
#      batches:
# ....................................
#    step 13: dcov = 16.017574024623833
#      batches:
# ....................................
#    step 14: dcov = 14.924305423867045
#      batches:
# ....................................
#    step 15: dcov = 15.170969607253458
#      batches:
# ....................................
#    step 16: dcov = 15.230991577638331
#      batches:
# ....................................
#    step 17: dcov = 15.04444532293936
#      batches:
# ....................................
#    step 18: dcov = 15.99829437024278
#      batches:
# ....................................
#    step 19: dcov = 15.537883853167827
#      batches:
# ....................................
#    step 20: dcov = 15.539121840680078
#      batches:
# ....................................
#    step 21: dcov = 15.154927307149583
#      batches:
# ....................................
#    step 22: dcov = 15.19757877527396
#      batches:
# ....................................
#    step 23: dcov = 15.500323221593678
#      batches:
# ....................................
#    step 24: dcov = 14.945202607994254
#      batches:
# ....................................
#    step 25: dcov = 15.105891735012806
#      batches:
# ....................................
#    step 26: dcov = 14.925152646386975
#      batches:
# ....................................
#    step 27: dcov = 15.202061860254455
#      batches:
# ....................................
#    step 28: dcov = 15.198980007333502
#      batches:
# ....................................
#    step 29: dcov = 15.15995082088268
#      batches:
# ....................................
#    step 30: dcov = 14.776870463323553
#      batches:
# ....................................
#
# dca dimension 2
#    step 1: dcov = 0.630658338504688
#      batches:
# ....................................
#    step 2: dcov = 10.035390294740855
#      batches:
# ....................................
#    step 3: dcov = 10.026410482728016
#      batches:
# ....................................
#    step 4: dcov = 10.2503277221722
#      batches:
# ....................................
#    step 5: dcov = 9.958463801501273
#      batches:
# ....................................
#    step 6: dcov = 10.166183973066262
#      batches:
# ....................................
#    step 7: dcov = 11.208728567840406
#      batches:
# ....................................
#    step 8: dcov = 11.929940117297999
#      batches:
# ....................................
#    step 9: dcov = 11.171705482971001
#      batches:
# ....................................
#    step 10: dcov = 10.58726838093504
#      batches:
# ....................................
#    step 11: dcov = 11.58308549854381
#      batches:
# ....................................
#    step 12: dcov = 11.871812464409757
#      batches:
# ....................................
#    step 13: dcov = 11.648583696312247
#      batches:
# ....................................
#    step 14: dcov = 11.932177206029637
#      batches:
# ....................................
#    step 15: dcov = 12.509598949852156
#      batches:
# ....................................
#    step 16: dcov = 11.490194572344093
#      batches:
# ....................................
#    step 17: dcov = 11.925412768101419
#      batches:
# ....................................
#    step 18: dcov = 11.530235969607467
#      batches:
# ....................................
#    step 19: dcov = 11.667206178254705
#      batches:
# ....................................
#    step 20: dcov = 12.339880925721422
#      batches:
# ....................................
#    step 21: dcov = 11.783524494936287
#      batches:
# ....................................
#    step 22: dcov = 12.055559203117197
#      batches:
# ....................................
#    step 23: dcov = 11.528171936275834
#      batches:
# ....................................
#    step 24: dcov = 11.888340971409578
#      batches:
# ....................................
#    step 25: dcov = 11.42219723221416
#      batches:
# ....................................
#    step 26: dcov = 11.675127350105411
#      batches:
# ....................................
#    step 27: dcov = 12.127808976396087
#      batches:
# ....................................
#    step 28: dcov = 12.13092851360605
#      batches:
# ....................................
#    step 29: dcov = 11.72980239372834
#      batches:
# ....................................
#    step 30: dcov = 11.80544794133055
#      batches:
# ....................................
#
# dca dimension 3
#    step 1: dcov = 0.7844520445552564
#      batches:
# ....................................
#    step 2: dcov = 2.236872885364563
#      batches:
# ....................................
#    step 3: dcov = 2.9188964298062396
#      batches:
# ....................................
#    step 4: dcov = 2.6473383735671443
#      batches:
# ....................................
#    step 5: dcov = 2.324116378762984
#      batches:
# ....................................
#    step 6: dcov = 3.071732223539706
#      batches:
# ....................................
#    step 7: dcov = 2.720564362904601
#      batches:
# ....................................
#    step 8: dcov = 3.1388768777876135
#      batches:
# ....................................
#    step 9: dcov = 3.262494764772667
#      batches:
# ....................................
#    step 10: dcov = 3.4202146648193916
#      batches:
# ....................................
#    step 11: dcov = 3.691606254564895
#      batches:
# ....................................
#    step 12: dcov = 3.17049795990731
#      batches:
# ....................................
#    step 13: dcov = 3.6174631529111076
#      batches:
# ....................................
#    step 14: dcov = 3.9662195065140176
#      batches:
# ....................................
#    step 15: dcov = 3.8469835242832264
#      batches:
# ....................................
#    step 16: dcov = 3.2447926527809408
#      batches:
# ....................................
#    step 17: dcov = 4.160459778389762
#      batches:
# ....................................
#    step 18: dcov = 3.6936614940327877
#      batches:
# ....................................
#    step 19: dcov = 4.022048058608905
#      batches:
# ....................................
#    step 20: dcov = 3.8903411308142384
#      batches:
# ....................................
#    step 21: dcov = 3.9144617760901554
#      batches:
# ....................................
#    step 22: dcov = 3.59227230965706
#      batches:
# ....................................
#    step 23: dcov = 4.002618360335263
#      batches:
# ....................................
#    step 24: dcov = 4.343862909832261
#      batches:
# ....................................
#    step 25: dcov = 4.627280362920918
#      batches:
# ....................................
#    step 26: dcov = 3.8938635574274816
#      batches:
# ....................................
#    step 27: dcov = 4.558246892769625
#      batches:
# ....................................
#    step 28: dcov = 3.8925899517321185
#      batches:
# ....................................
#    step 29: dcov = 4.390195713091942
#      batches:
# ....................................
#    step 30: dcov = 4.906709718883406
#      batches:
# ....................................
#
# dca dimension 4
#    step 1: dcov = 0.6104981130241101
#      batches:
# ....................................
#    step 2: dcov = 1.2825727522396138
#      batches:
# ....................................
#    step 3: dcov = 1.539073969741044
#      batches:
# ....................................
#    step 4: dcov = 1.963962613916749
#      batches:
# ....................................
#    step 5: dcov = 2.0646886072008126
#      batches:
# ....................................
#    step 6: dcov = 2.131361806403365
#      batches:
# ....................................
#    step 7: dcov = 2.3066241706888264
#      batches:
# ....................................
#    step 8: dcov = 2.2371151663665994
#      batches:
# ....................................
#    step 9: dcov = 2.7715951525626323
#      batches:
# ....................................
#    step 10: dcov = 2.4882192203286495
#      batches:
# ....................................
#    step 11: dcov = 2.6753824496488203
#      batches:
# ....................................
#    step 12: dcov = 2.896808410179964
#      batches:
# ....................................
#    step 13: dcov = 2.4427361871467497
#      batches:
# ....................................
#    step 14: dcov = 2.910368654535589
#      batches:
# ....................................
#    step 15: dcov = 3.360332496291663
#      batches:
# ....................................
#    step 16: dcov = 3.389422709803821
#      batches:
# ....................................
#    step 17: dcov = 3.169638857897526
#      batches:
# ....................................
#    step 18: dcov = 3.5959743098462766
#      batches:
# ....................................
#    step 19: dcov = 3.6767932611294203
#      batches:
# ....................................
#    step 20: dcov = 3.756701391791975
#      batches:
# ....................................
#    step 21: dcov = 3.8006030092110112
#      batches:
# ....................................
#    step 22: dcov = 3.902361496217438
#      batches:
# ....................................
#    step 23: dcov = 4.07898522167476
#      batches:
# ....................................
#    step 24: dcov = 4.120296069051309
#      batches:
# ....................................
#    step 25: dcov = 4.143100415212052
#      batches:
# ....................................
#    step 26: dcov = 4.30353093593592
#      batches:
# ....................................
#    step 27: dcov = 4.225474098524654
#      batches:
# ....................................
#    step 28: dcov = 4.455278243566263
#      batches:
# ....................................
#    step 29: dcov = 4.179680699911828
#      batches:
# ....................................
#    step 30: dcov = 4.64019123803515
#      batches:
# ....................................
#
# dca dimension 5
#    step 1: dcov = 0.6125295392781603
#      batches:
# ....................................
#    step 2: dcov = 1.1259127876285981
#      batches:
# ....................................
#    step 3: dcov = 1.8834354195077407
#      batches:
# ....................................
#    step 4: dcov = 1.5207504228422422
#      batches:
# ....................................
#    step 5: dcov = 1.8072559107426476
#      batches:
# ....................................
#    step 6: dcov = 2.276215294142717
#      batches:
# ....................................
#    step 7: dcov = 2.1790388827673133
#      batches:
# ....................................
#    step 8: dcov = 2.735391894920184
#      batches:
# ....................................
#    step 9: dcov = 2.3585038068534954
#      batches:
# ....................................
#    step 10: dcov = 2.4094990628426904
#      batches:
# ....................................
#    step 11: dcov = 2.442482880295614
#      batches:
# ....................................
#    step 12: dcov = 2.740745790610487
#      batches:
# ....................................
#    step 13: dcov = 3.1902080685877396
#      batches:
# ....................................
#    step 14: dcov = 3.310822584176931
#      batches:
# ....................................
#    step 15: dcov = 3.072358217161016
#      batches:
# ....................................
#    step 16: dcov = 3.1739074256820743
#      batches:
# ....................................
#    step 17: dcov = 3.227085976505265
#      batches:
# ....................................
#    step 18: dcov = 3.2699024885542394
#      batches:
# ....................................
#    step 19: dcov = 3.4952116114304257
#      batches:
# ....................................
#    step 20: dcov = 3.6065444063912073
#      batches:
# ....................................
#    step 21: dcov = 3.6128000497489756
#      batches:
# ....................................
#    step 22: dcov = 3.8672187360243813
#      batches:
# ....................................
#    step 23: dcov = 3.927032568153593
#      batches:
# ....................................
#    step 24: dcov = 3.9041198345283363
#      batches:
# ....................................
#    step 25: dcov = 4.149143939405118
#      batches:
# ....................................
#    step 26: dcov = 4.088313152019639
#      batches:
# ....................................
#    step 27: dcov = 4.008387754983081
#      batches:
# ....................................
#    step 28: dcov = 4.400130857674056
#      batches:
# ....................................
#    step 29: dcov = 4.127826308481324
#      batches:
# ....................................
#    step 30: dcov = 4.216977339944655
#      batches:
# ....................................
#
# dca dimension 6
#    step 1: dcov = 0.6518033150185245
#      batches:
# ....................................
#    step 2: dcov = 0.8965106290438776
#      batches:
# ....................................
#    step 3: dcov = 0.8365555254600818
#      batches:
# ....................................
#    step 4: dcov = 0.7613352615072455
#      batches:
# ....................................
#    step 5: dcov = 0.6073599780955709
#      batches:
# ....................................
#    step 6: dcov = 0.9364270903781281
#      batches:
# ....................................
#    step 7: dcov = 0.8683881194783519
#      batches:
# ....................................
#    step 8: dcov = 0.8502241580408273
#      batches:
# ....................................
#    step 9: dcov = 0.7317339807860771
#      batches:
# ....................................
#    step 10: dcov = 0.7461634203090122
#      batches:
# ....................................
#    step 11: dcov = 0.8020422959835692
#      batches:
# ....................................
#    step 12: dcov = 0.7958987581409817
#      batches:
# ....................................
#    step 13: dcov = 0.9551661896363848
#      batches:
# ....................................
#    step 14: dcov = 1.062746338097194
#      batches:
# ....................................
#    step 15: dcov = 1.1201438593551223
#      batches:
# ....................................
#    step 16: dcov = 0.9541729725621626
#      batches:
# ....................................
#    step 17: dcov = 1.0541431095038212
#      batches:
# ....................................
#    step 18: dcov = 1.5380483107948246
#      batches:
# ....................................
#    step 19: dcov = 1.6047761528941717
#      batches:
# ....................................
#    step 20: dcov = 1.4897151378482707
#      batches:
# ....................................
#    step 21: dcov = 2.1650352035151905
#      batches:
# ....................................
#    step 22: dcov = 1.9409600103829892
#      batches:
# ....................................
#    step 23: dcov = 1.8367928918774645
#      batches:
# ....................................
#    step 24: dcov = 2.038354578574235
#      batches:
# ....................................
#    step 25: dcov = 1.9944305634639823
#      batches:
# ....................................
#    step 26: dcov = 2.4654076720217355
#      batches:
# ....................................
#    step 27: dcov = 2.4290694980814984
#      batches:
# ....................................
#    step 28: dcov = 2.705543556031049
#      batches:
# ....................................
#    step 29: dcov = 2.5537327483613037
#      batches:
# ....................................
#    step 30: dcov = 2.8468580966841466
#      batches:
# ....................................
#
# dca dimension 7
#    step 1: dcov = 0.6745218545541736
#      batches:
# ....................................
#    step 2: dcov = 0.7541975982202688
#      batches:
# ....................................
#    step 3: dcov = 0.7417673349351959
#      batches:
# ....................................
#    step 4: dcov = 0.7614071342150138
#      batches:
# ....................................
#    step 5: dcov = 0.8452019429192252
#      batches:
# ....................................
#    step 6: dcov = 0.7825134600178478
#      batches:
# ....................................
#    step 7: dcov = 0.7614083655138517
#      batches:
# ....................................
#    step 8: dcov = 0.6590789767973552
#      batches:
# ....................................
#    step 9: dcov = 0.8954907963207962
#      batches:
# ....................................
#    step 10: dcov = 0.7777124986038763
#      batches:
# ....................................
#    step 11: dcov = 0.667132030963965
#      batches:
# ....................................
#    step 12: dcov = 0.9042369038293484
#      batches:
# ....................................
#    step 13: dcov = 0.8847059410836632
#      batches:
# ....................................
#    step 14: dcov = 0.7231277731894421
#      batches:
# ....................................
#    step 15: dcov = 0.9402189959487687
#      batches:
# ....................................
#    step 16: dcov = 1.0216067918001113
#      batches:
# ....................................
#    step 17: dcov = 1.2401602248529515
#      batches:
# ....................................
#    step 18: dcov = 1.2068018878753315
#      batches:
# ....................................
#    step 19: dcov = 0.9270278320692601
#      batches:
# ....................................
#    step 20: dcov = 1.0324580989867134
#      batches:
# ....................................
#    step 21: dcov = 1.455062814215934
#      batches:
# ....................................
#    step 22: dcov = 1.3128115766729767
#      batches:
# ....................................
#    step 23: dcov = 1.2855642025130503
#      batches:
# ....................................
#    step 24: dcov = 1.589245870033459
#      batches:
# ....................................
#    step 25: dcov = 1.379945055531368
#      batches:
# ....................................
#    step 26: dcov = 1.7233907705320015
#      batches:
# ....................................
#    step 27: dcov = 2.153132006362068
#      batches:
# ....................................
#    step 28: dcov = 2.000475612073077
#      batches:
# ....................................
#    step 29: dcov = 1.8881393491521778
#      batches:
# ....................................
#    step 30: dcov = 1.9188429595377112
#      batches:
# ....................................
#
# dca dimension 8
#    step 1: dcov = 0.6021822868911644
#      batches:
# ....................................
#    step 2: dcov = 0.8479370617630408
#      batches:
# ....................................
#    step 3: dcov = 0.7627506504826495
#      batches:
# ....................................
#    step 4: dcov = 0.8288650337578488
#      batches:
# ....................................
#    step 5: dcov = 0.7992782948690438
#      batches:
# ....................................
#    step 6: dcov = 0.8106892204938445
#      batches:
# ....................................
#    step 7: dcov = 0.672899367248084
#      batches:
# ....................................
#    step 8: dcov = 1.0847329353327206
#      batches:
# ....................................
#    step 9: dcov = 0.8764895591804652
#      batches:
# ....................................
#    step 10: dcov = 1.0943519081880728
#      batches:
# ....................................
#    step 11: dcov = 0.8051218084904433
#      batches:
# ....................................
#    step 12: dcov = 0.7808885171731328
#      batches:
# ....................................
#    step 13: dcov = 0.7566370426841946
#      batches:
# ....................................
#    step 14: dcov = 0.8338854525528527
#      batches:
# ....................................
#    step 15: dcov = 1.0001947191979472
#      batches:
# ....................................
#    step 16: dcov = 0.8276652845205773
#      batches:
# ....................................
#    step 17: dcov = 0.8311973281656222
#      batches:
# ....................................
#    step 18: dcov = 0.993761137908449
#      batches:
# ....................................
#    step 19: dcov = 0.9522622641499221
#      batches:
# ....................................
#    step 20: dcov = 1.1729724687605785
#      batches:
# ....................................
#    step 21: dcov = 1.1148344416954359
#      batches:
# ....................................
#    step 22: dcov = 1.5005113872058575
#      batches:
# ....................................
#    step 23: dcov = 1.3733299754487287
#      batches:
# ....................................
#    step 24: dcov = 1.6738972894799669
#      batches:
# ....................................
#    step 25: dcov = 1.9062006342585263
#      batches:
# ....................................
#    step 26: dcov = 1.7487879766043533
#      batches:
# ....................................
#    step 27: dcov = 2.060338067900746
#      batches:
# ....................................
#    step 28: dcov = 1.8082085105766106
#      batches:
# ....................................
#    step 29: dcov = 1.939428122422249
#      batches:
# ....................................
#    step 30: dcov = 2.084225953123893
#      batches:
# ....................................
#
# dca dimension 9
#    step 1: dcov = 0.7304779832007869
#      batches:
# ....................................
#    step 2: dcov = 0.8182770504012725
#      batches:
# ....................................
#    step 3: dcov = 0.8174510558424009
#      batches:
# ....................................
#    step 4: dcov = 0.6659777233639135
#      batches:
# ....................................
#    step 5: dcov = 0.6005048942740445
#      batches:
# ....................................
#    step 6: dcov = 0.6873999396727929
#      batches:
# ....................................
#    step 7: dcov = 0.6259212383659027
#      batches:
# ....................................
#    step 8: dcov = 0.7943256968241273
#      batches:
# ....................................
#    step 9: dcov = 0.7157431088402817
#      batches:
# ....................................
#    step 10: dcov = 0.7243022146205108
#      batches:
# ....................................
#    step 11: dcov = 0.7270446216233134
#      batches:
# ....................................
#    step 12: dcov = 0.781539298049899
#      batches:
# ....................................
#    step 13: dcov = 0.7785599883433688
#      batches:
# ....................................
#    step 14: dcov = 0.7198204379757218
#      batches:
# ....................................
#    step 15: dcov = 1.0265135012394961
#      batches:
# ....................................
#    step 16: dcov = 0.7907507264062139
#      batches:
# ....................................
#    step 17: dcov = 0.862695239355124
#      batches:
# ....................................
#    step 18: dcov = 0.9015065513211606
#      batches:
# ....................................
#    step 19: dcov = 1.0248308608091545
#      batches:
# ....................................
#    step 20: dcov = 0.951919592693882
#      batches:
# ....................................
#    step 21: dcov = 1.1266250474800932
#      batches:
# ....................................
#    step 22: dcov = 1.496625815122967
#      batches:
# ....................................
#    step 23: dcov = 1.3852143959119416
#      batches:
# ....................................
#    step 24: dcov = 1.586941721568764
#      batches:
# ....................................
#    step 25: dcov = 1.8094702251579986
#      batches:
# ....................................
#    step 26: dcov = 1.6534856770796535
#      batches:
# ....................................
#    step 27: dcov = 1.7150502571483095
#      batches:
# ....................................
#    step 28: dcov = 1.9547176822390049
#      batches:
# ....................................
#    step 29: dcov = 2.0289161178866895
#      batches:
# ....................................
#    step 30: dcov = 2.122625168393766
#      batches:
# ....................................
#
# dca dimension 10
#    step 1: dcov = 0.6757732097548618
#      batches:
# ....................................
#    step 2: dcov = 0.6109584647491461
#      batches:
# ....................................
#    step 3: dcov = 0.8753867913240899
#      batches:
# ....................................
#    step 4: dcov = 0.5789446921611167
#      batches:
# ....................................
#    step 5: dcov = 0.7492724378602582
#      batches:
# ....................................
#    step 6: dcov = 0.8469449466145885
#      batches:
# ....................................
#    step 7: dcov = 0.766708173606613
#      batches:
# ....................................
#    step 8: dcov = 0.7736432087393829
#      batches:
# ....................................
#    step 9: dcov = 0.604858275777865
#      batches:
# ....................................
#    step 10: dcov = 0.5681524997842312
#      batches:
# ....................................
#    step 11: dcov = 0.7599512278789616
#      batches:
# ....................................
#    step 12: dcov = 0.7813007251766
#      batches:
# ....................................
#    step 13: dcov = 1.1135311654304365
#      batches:
# ....................................
#    step 14: dcov = 0.7755401791741885
#      batches:
# ....................................
#    step 15: dcov = 0.7433413841970796
#      batches:
# ....................................
#    step 16: dcov = 0.7998474477051765
#      batches:
# ....................................
#    step 17: dcov = 0.7615734823326804
#      batches:
# ....................................
#    step 18: dcov = 0.9490973314820155
#      batches:
# ....................................
#    step 19: dcov = 0.7372894227693263
#      batches:
# ....................................
#    step 20: dcov = 0.8387038963586371
#      batches:
# ....................................
#    step 21: dcov = 0.9444799104581572
#      batches:
# ....................................
#    step 22: dcov = 1.1362847637946307
#      batches:
# ....................................
#    step 23: dcov = 1.2500114336716839
#      batches:
# ....................................
#    step 24: dcov = 1.1801284499026912
#      batches:
# ....................................
#    step 25: dcov = 1.4913766625817142
#      batches:
# ....................................
#    step 26: dcov = 1.0101971599746253
#      batches:
# ....................................
#    step 27: dcov = 1.6252718036470246
#      batches:
# ....................................
#    step 28: dcov = 1.520924502251244
#      batches:
# ....................................
#    step 29: dcov = 1.8922029153895719
#      batches:
# ....................................
#    step 30: dcov = 2.0382759326235056
#      batches:
# ....................................
#
# dca dimension 11
#    step 1: dcov = 0.5872036484642962
#      batches:
# ....................................
#    step 2: dcov = 0.814453323699259
#      batches:
# ....................................
#    step 3: dcov = 0.7624011997654516
#      batches:
# ....................................
#    step 4: dcov = 0.6752846119537623
#      batches:
# ....................................
#    step 5: dcov = 0.735691193894818
#      batches:
# ....................................
#    step 6: dcov = 0.6837528988499749
#      batches:
# ....................................
#    step 7: dcov = 0.9860183089753769
#      batches:
# ....................................
#    step 8: dcov = 0.6921108498476178
#      batches:
# ....................................
#    step 9: dcov = 0.7214590229880908
#      batches:
# ....................................
#    step 10: dcov = 0.6841302495875934
#      batches:
# ....................................
#    step 11: dcov = 0.7809593167106191
#      batches:
# ....................................
#    step 12: dcov = 0.8377068234514132
#      batches:
# ....................................
#    step 13: dcov = 0.7795540122774924
#      batches:
# ....................................
#    step 14: dcov = 0.8448346103836343
#      batches:
# ....................................
#    step 15: dcov = 0.9115671948812349
#      batches:
# ....................................
#    step 16: dcov = 0.8693141319178564
#      batches:
# ....................................
#    step 17: dcov = 0.8671623869576898
#      batches:
# ....................................
#    step 18: dcov = 0.8103104355850741
#      batches:
# ....................................
#    step 19: dcov = 0.9032171832840888
#      batches:
# ....................................
#    step 20: dcov = 1.0591387427387144
#      batches:
# ....................................
#    step 21: dcov = 1.0108888933378544
#      batches:
# ....................................
#    step 22: dcov = 0.888392533466842
#      batches:
# ....................................
#    step 23: dcov = 0.8894253166301931
#      batches:
# ....................................
#    step 24: dcov = 1.131082979440701
#      batches:
# ....................................
#    step 25: dcov = 1.0076062632626643
#      batches:
# ....................................
#    step 26: dcov = 1.3951406017273302
#      batches:
# ....................................
#    step 27: dcov = 1.40796701779622
#      batches:
# ....................................
#    step 28: dcov = 1.5497069469944358
#      batches:
# ....................................
#    step 29: dcov = 1.7390082881823392
#      batches:
# ....................................
#    step 30: dcov = 1.7008984678272667
#      batches:
# ....................................
#
# dca dimension 12
#    step 1: dcov = 0.6179367393902967
#      batches:
# ....................................
#    step 2: dcov = 0.746703919458182
#      batches:
# ....................................
#    step 3: dcov = 0.7285965045488066
#      batches:
# ....................................
#    step 4: dcov = 0.6745885236423201
#      batches:
# ....................................
#    step 5: dcov = 0.759708329002605
#      batches:
# ....................................
#    step 6: dcov = 0.7681918922952073
#      batches:
# ....................................
#    step 7: dcov = 0.7889463853887464
#      batches:
# ....................................
#    step 8: dcov = 0.714861716177438
#      batches:
# ....................................
#    step 9: dcov = 0.8177327009809864
#      batches:
# ....................................
#    step 10: dcov = 0.7286539979118056
#      batches:
# ....................................
#    step 11: dcov = 0.9150234527258182
#      batches:
# ....................................
#    step 12: dcov = 0.7434697677612598
#      batches:
# ....................................
#    step 13: dcov = 0.7736899525308129
#      batches:
# ....................................
#    step 14: dcov = 0.835605069761412
#      batches:
# ....................................
#    step 15: dcov = 0.7830428885849534
#      batches:
# ....................................
#    step 16: dcov = 0.8248721330750177
#      batches:
# ....................................
#    step 17: dcov = 0.8494657313167685
#      batches:
# ....................................
#    step 18: dcov = 0.8917515224748388
#      batches:
# ....................................
#    step 19: dcov = 1.0685810040972252
#      batches:
# ....................................
#    step 20: dcov = 0.9861970673444033
#      batches:
# ....................................
#    step 21: dcov = 1.0696405760233871
#      batches:
# ....................................
#    step 22: dcov = 1.049776489305514
#      batches:
# ....................................
#    step 23: dcov = 1.0891097496141282
#      batches:
# ....................................
#    step 24: dcov = 0.9170013004740719
#      batches:
# ....................................
#    step 25: dcov = 0.988984213002669
#      batches:
# ....................................
#    step 26: dcov = 0.976926585945049
#      batches:
# ....................................
#    step 27: dcov = 1.2699238949784704
#      batches:
# ....................................
#    step 28: dcov = 1.2765015597911444
#      batches:
# ....................................
#    step 29: dcov = 1.355204917566251
#      batches:
# ....................................
#    step 30: dcov = 1.4443233139225118
#      batches:
# ....................................
#
# dca dimension 13
#    step 1: dcov = 0.6114845804361653
#      batches:
# ....................................
#    step 2: dcov = 0.7633656249163921
#      batches:
# ....................................
#    step 3: dcov = 0.7851026935532832
#      batches:
# ....................................
#    step 4: dcov = 0.7694974548106367
#      batches:
# ....................................
#    step 5: dcov = 0.6185006448224012
#      batches:
# ....................................
#    step 6: dcov = 0.523155969407816
#      batches:
# ....................................
#    step 7: dcov = 0.8368577148361118
#      batches:
# ....................................
#    step 8: dcov = 1.0038826501828606
#      batches:
# ....................................
#    step 9: dcov = 0.9390173169560607
#      batches:
# ....................................
#    step 10: dcov = 0.7549584106244382
#      batches:
# ....................................
#    step 11: dcov = 0.8778147805870501
#      batches:
# ....................................
#    step 12: dcov = 0.7729610029129195
#      batches:
# ....................................
#    step 13: dcov = 0.7681198528956241
#      batches:
# ....................................
#    step 14: dcov = 0.9941014383276717
#      batches:
# ....................................
#    step 15: dcov = 0.8877065514428445
#      batches:
# ....................................
#    step 16: dcov = 0.6980564839569849
#      batches:
# ....................................
#    step 17: dcov = 0.8903907293247656
#      batches:
# ....................................
#    step 18: dcov = 0.9734777850156726
#      batches:
# ....................................
#    step 19: dcov = 0.8804652643451595
#      batches:
# ....................................
#    step 20: dcov = 1.1588574880273605
#      batches:
# ....................................
#    step 21: dcov = 0.8326595893467134
#      batches:
# ....................................
#    step 22: dcov = 0.9996244943074396
#      batches:
# ....................................
#    step 23: dcov = 0.9614870573129898
#      batches:
# ....................................
#    step 24: dcov = 1.4608307400612657
#      batches:
# ....................................
#    step 25: dcov = 1.2633130574356723
#      batches:
# ....................................
#    step 26: dcov = 1.1239826753629607
#      batches:
# ....................................
#    step 27: dcov = 1.3878953576078905
#      batches:
# ....................................
#    step 28: dcov = 1.1606073449618626
#      batches:
# ....................................
#    step 29: dcov = 1.569403267808315
#      batches:
# ....................................
#    step 30: dcov = 1.3414658971556155
#      batches:
# ....................................
#
# dca dimension 14
#    step 1: dcov = 0.7022100603795162
#      batches:
# ....................................
#    step 2: dcov = 0.5621317578609688
#      batches:
# ....................................
#    step 3: dcov = 0.6248017538211037
#      batches:
# ....................................
#    step 4: dcov = 0.9557413401843826
#      batches:
# ....................................
#    step 5: dcov = 0.654970122287308
#      batches:
# ....................................
#    step 6: dcov = 0.9499343796808323
#      batches:
# ....................................
#    step 7: dcov = 0.6122424577987176
#      batches:
# ....................................
#    step 8: dcov = 0.7801476591456762
#      batches:
# ....................................
#    step 9: dcov = 0.7090955305145223
#      batches:
# ....................................
#    step 10: dcov = 0.8325213785848413
#      batches:
# ....................................
#    step 11: dcov = 0.7625702531126115
#      batches:
# ....................................
#    step 12: dcov = 0.7766417051744415
#      batches:
# ....................................
#    step 13: dcov = 0.7331742144730501
#      batches:
# ....................................
#    step 14: dcov = 0.813641197669797
#      batches:
# ....................................
#    step 15: dcov = 0.6804143199660471
#      batches:
# ....................................
#    step 16: dcov = 0.7702910900261151
#      batches:
# ....................................
#    step 17: dcov = 0.819448392410868
#      batches:
# ....................................
#    step 18: dcov = 0.8927279155031358
#      batches:
# ....................................
#    step 19: dcov = 1.0290901563943
#      batches:
# ....................................
#    step 20: dcov = 0.9035173357701328
#      batches:
# ....................................
#    step 21: dcov = 0.9867006017582832
#      batches:
# ....................................
#    step 22: dcov = 0.9945866066259438
#      batches:
# ....................................
#    step 23: dcov = 0.9285296783155728
#      batches:
# ....................................
#    step 24: dcov = 1.0790019325148483
#      batches:
# ....................................
#    step 25: dcov = 1.0743735333768223
#      batches:
# ....................................
#    step 26: dcov = 0.833452930159014
#      batches:
# ....................................
#    step 27: dcov = 1.2699956323837946
#      batches:
# ....................................
#    step 28: dcov = 1.4994277431021263
#      batches:
# ....................................
#    step 29: dcov = 1.4084865276940695
#      batches:
# ....................................
#    step 30: dcov = 1.6300265617621514
#      batches:
# ....................................
#
# dca dimension 15
#    step 1: dcov = 0.698731159425123
#      batches:
# ....................................
#    step 2: dcov = 0.6786514215835634
#      batches:
# ....................................
#    step 3: dcov = 0.6421603959460009
#      batches:
# ....................................
#    step 4: dcov = 0.6763203897558107
#      batches:
# ....................................
#    step 5: dcov = 0.7198582917204029
#      batches:
# ....................................
#    step 6: dcov = 0.6011996881426255
#      batches:
# ....................................
#    step 7: dcov = 0.7661345967513432
#      batches:
# ....................................
#    step 8: dcov = 0.7536883861378795
#      batches:
# ....................................
#    step 9: dcov = 0.6001664536825435
#      batches:
# ....................................
#    step 10: dcov = 0.847312466214109
#      batches:
# ....................................
#    step 11: dcov = 0.8054295435206833
#      batches:
# ....................................
#    step 12: dcov = 0.8296730386048756
#      batches:
# ....................................
#    step 13: dcov = 0.7552657293456402
#      batches:
# ....................................
#    step 14: dcov = 0.6795871253411473
#      batches:
# ....................................
#    step 15: dcov = 1.0215424754895446
#      batches:
# ....................................
#    step 16: dcov = 0.8294702780820726
#      batches:
# ....................................
#    step 17: dcov = 0.6919315686268385
#      batches:
# ....................................
#    step 18: dcov = 0.848375964733854
#      batches:
# ....................................
#    step 19: dcov = 0.7904022129129737
#      batches:
# ....................................
#    step 20: dcov = 0.8124432625688144
#      batches:
# ....................................
#    step 21: dcov = 0.8651934157604272
#      batches:
# ....................................
#    step 22: dcov = 0.8828987410858014
#      batches:
# ....................................
#    step 23: dcov = 0.8035171586375096
#      batches:
# ....................................
#    step 24: dcov = 1.218279042756785
#      batches:
# ....................................
#    step 25: dcov = 1.2592969559230895
#      batches:
# ....................................
#    step 26: dcov = 1.1374289653603924
#      batches:
# ....................................
#    step 27: dcov = 1.2432614878910195
#      batches:
# ....................................
#    step 28: dcov = 1.1975487240325593
#      batches:
# ....................................
#    step 29: dcov = 1.3288018771399366
#      batches:
# ....................................
#    step 30: dcov = 1.5802510209413583
#      batches:
# ....................................

# %%
# 6) outputs
U = U_list[0]                 # (genes x K)
Z = (X_gc.T) @ U              # (cells x genes) @ (genes x K) -> (cells x K)

# %%
# 7) Save to CSV with labels
k_actual = U.shape[1]
cols = [f"DCA{i+1}" for i in range(k_actual)]

U_df = pd.DataFrame(U, index=gene_names, columns=cols)   # loadings (genes x K)
Z_df = pd.DataFrame(Z, index=cell_ids,  columns=cols)    # scores   (cells x K)

dcovs = np.asarray(dcovs).reshape(-1)
dc_df = pd.DataFrame({"dimension": [f"DCA{i+1}" for i in range(len(dcovs))],
                      "distance_covariance": dcovs})

U_df.to_csv("/Users/nanxi/Documents/ZhangLab/Spatial_transcriptomics/Spatial_clusters/DCA/Output/Sim3_U_DCA.csv")
Z_df.to_csv("/Users/nanxi/Documents/ZhangLab/Spatial_transcriptomics/Spatial_clusters/DCA/Output/Sim3_Z_DCA.csv")
dc_df.to_csv("/Users/nanxi/Documents/ZhangLab/Spatial_transcriptomics/Spatial_clusters/DCA/Output/Sim3_dcovs.csv", index=False)

# %%
# 7) save
np.save("U_DCA.npy", U)               # gene loadings
np.save("Z_DCA.npy", Z)               # cell embeddings
np.save("dcovs.npy", np.array(dcovs)) # distance-covariance per DCA dim 
print("Saved: U_DCA.npy, Z_DCA.npy, dcovs.npy")
